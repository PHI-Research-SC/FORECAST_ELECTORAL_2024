# %%
import pandas as pd
#Load file
df = pd.read_excel('/content/Base_FINAL.xlsx')

# %%
# Filters
df = df[(df['AÑO'] >= 2018) & (~df['TIPO'].isin(['EST', 'OTRAS']))]

# %%
import time
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
import xgboost as xgb
import lightgbm as lgb
from sklearn.utils import resample
from tqdm import tqdm

# Prepare features and labels
X_features = df.drop(columns=['TIPO', 'AÑO', 'MORENA', 'PRIANPRD', 'OTROS'])
y = df[['MORENA', 'PRIANPRD', 'OTROS']]

# Convert categorical 'EDO' column to numeric using one-hot encoding
X_features = pd.get_dummies(X_features, columns=['EDO'], drop_first=True)

# Define function to calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred, threshold=1e-2):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    mask = y_true > threshold
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

# Initialize dictionaries to store metrics and predictions
mse_scores = {}
mae_scores = {}
mape_scores = {}
trained_models = {}

# Multi-output models
multi_output_models = {
    'Random Forest': RandomForestRegressor(n_estimators=100, random_state=42),
    'Gradient Boosting': GradientBoostingRegressor(n_estimators=100, random_state=42),
    'XGBoost': xgb.XGBRegressor(n_estimators=100, random_state=42),
    'LightGBM': lgb.LGBMRegressor(n_estimators=100, random_state=42)
}

# Single-output models
single_output_models = {
    'Linear Regression': LinearRegression(),
    'SVR': SVR(kernel='rbf'),
    'KNN': KNeighborsRegressor(n_neighbors=3)
}

# Train and evaluate multi-output models using MultiOutputRegressor on the entire dataset
for name, model in multi_output_models.items():
    multi_model = MultiOutputRegressor(model)
    multi_model.fit(X_features, y)
    preds = multi_model.predict(X_features)
    mse_scores[name] = mean_squared_error(y, preds)
    mae_scores[name] = mean_absolute_error(y, preds)
    mape_scores[name] = mean_absolute_percentage_error(y, preds)
    trained_models[name] = multi_model

# Train and evaluate single-output models on the entire dataset
for name, model in single_output_models.items():
    model_mse = []
    model_mae = []
    model_mape = []
    preds_list = []
    trained_model_list = []

    for i in range(y.shape[1]):
        model.fit(X_features, y.iloc[:, i])
        preds = model.predict(X_features)
        preds_list.append(preds)
        model_mse.append(mean_squared_error(y.iloc[:, i], preds))
        model_mae.append(mean_absolute_error(y.iloc[:, i], preds))
        model_mape.append(mean_absolute_percentage_error(y.iloc[:, i], preds))
        trained_model_list.append(model)

    mse_scores[name] = np.mean(model_mse)
    mae_scores[name] = np.mean(model_mae)
    mape_scores[name] = np.mean(model_mape)
    trained_models[name] = trained_model_list

# Select the top three models based on the lowest errors
sorted_models = sorted(mae_scores.items(), key=lambda item: (item[1], mape_scores[item[0]], mse_scores[item[0]]))
top_three_models = [model[0] for model in sorted_models[:3]]

# Create a DataFrame to display the errors of the top three models
top_three_errors = pd.DataFrame(
    [(model, mse_scores[model], mae_scores[model], mape_scores[model]) for model in top_three_models],
    columns=['Model', 'MSE', 'MAE', 'MAPE']
)

# Display the DataFrame with the top three models and their errors
print("Top Three Models with Lowest Errors:")
print(top_three_errors)

# Timing the process
start_time = time.time()

# Initialize dictionary to store predictions per EDO
predictions_per_edo = {}
ci_per_edo = {}

# Get unique labels in the 'EDO' column
unique_edos = df['EDO'].unique()

# Number of bootstrap samples
n_bootstrap_samples = 100  # Reduced to 100 for faster computation

# General prediction
general_predictions = {}
general_ci = {}

# Calculate general predictions and confidence intervals
for name in top_three_models:
    multi_model = trained_models[name]
    preds_samples = []

    for _ in tqdm(range(n_bootstrap_samples), desc=f"Bootstrap sampling for general {name}"):
        X_resampled = resample(X_features)
        preds_resampled = multi_model.predict(X_resampled)
        preds_samples.append(preds_resampled.mean(axis=0))

    preds_samples = np.array(preds_samples)
    preds_mean = preds_samples.mean(axis=0)
    preds_lower = np.percentile(preds_samples, 2.5, axis=0)
    preds_upper = np.percentile(preds_samples, 97.5, axis=0)

    general_predictions[name] = preds_mean
    general_ci[name] = (preds_lower, preds_upper)

# Iterate over each unique 'EDO' label
for edo in tqdm(unique_edos, desc="Processing EDOs"):
    # Create a dummy data point for prediction for the given EDO
    X_new_period_edo = X_features.mean().to_frame().T
    X_new_period_edo['EDO_' + str(edo)] = 1  # Add one-hot encoded EDO column

    # Ensure the new period data has the same columns as the training set
    X_new_period_edo = X_new_period_edo.reindex(columns=X_features.columns, fill_value=0)

    # Store predictions and confidence intervals for the top three models
    for name in top_three_models:
        multi_model = trained_models[name]

        # Bootstrap sampling to calculate confidence intervals
        preds_samples = []
        for _ in range(n_bootstrap_samples):
            preds_resampled = multi_model.predict(X_new_period_edo)
            preds_samples.append(preds_resampled.flatten())  # Removed normalization step here

        preds_samples = np.array(preds_samples)
        preds_mean = preds_samples.mean(axis=0)
        preds_lower = np.percentile(preds_samples, 2.5, axis=0)
        preds_upper = np.percentile(preds_samples, 97.5, axis=0)

        predictions_per_edo.setdefault(name, []).append(preds_mean)
        ci_per_edo.setdefault(name, []).append((preds_lower, preds_upper))

# Timing end
end_time = time.time()
total_time = end_time - start_time

# Convert general predictions to DataFrames and add labels
general_predictions_df = {name: pd.DataFrame([preds], columns=['MORENA', 'PRIANPRD', 'OTROS']) for name, preds in general_predictions.items()}

# Convert EDO predictions to DataFrames and add labels
predictions_df_per_edo = {name: pd.DataFrame(preds, index=unique_edos, columns=['MORENA', 'PRIANPRD', 'OTROS']) for name, preds in predictions_per_edo.items()}

# Display the general predictions and confidence intervals
for name, df in general_predictions_df.items():
    print(f"\n{name} general predictions for the next period:")
    print(df)
    lower_ci = general_ci[name][0]
    upper_ci = general_ci[name][1]
    print(f"95% Confidence Intervals for {name}:")
    print(f"Lower - MORENA: {lower_ci[0]:.4f}, PRIANPRD: {lower_ci[1]:.4f}, OTROS: {lower_ci[2]:.4f}")
    print(f"Upper - MORENA: {upper_ci[0]:.4f}, PRIANPRD: {upper_ci[1]:.4f}, OTROS: {upper_ci[2]:.4f}")

# Display the DataFrames with EDO predictions and confidence intervals
for name, df in predictions_df_per_edo.items():
    print(f"\n{name} predictions per EDO for the next period:")
    print(df)
    print(f"95% Confidence Intervals for {name}:")
    for i, edo in enumerate(unique_edos):
        lower_ci = ci_per_edo[name][i][0]
        upper_ci = ci_per_edo[name][i][1]
        print(f"{edo}: Lower - MORENA: {lower_ci[0]:.4f}, PRIANPRD: {lower_ci[1]:.4f}, OTROS: {lower_ci[2]:.4f}")
        print(f"       Upper - MORENA: {upper_ci[0]:.4f}, PRIANPRD: {upper_ci[1]:.4f}, OTROS: {upper_ci[2]:.4f}")

print(f"Total execution time: {total_time:.2f} seconds")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000079 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 100
# [LightGBM] [Info] Number of data points in the train set: 220, number of used features: 4
# [LightGBM] [Info] Start training from score 0.527188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000044 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 100
# [LightGBM] [Info] Number of data points in the train set: 220, number of used features: 4
# [LightGBM] [Info] Start training from score 0.403964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000041 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 100
# [LightGBM] [Info] Number of data points in the train set: 220, number of used features: 4
# [LightGBM] [Info] Start training from score 0.067439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Top Three Models with Lowest Errors:
#                Model       MSE       MAE       MAPE
# 0            XGBoost  0.001751  0.019611  11.197331
# 1      Random Forest  0.002201  0.031051  16.081092
# 2  Gradient Boosting  0.002525  0.035253  17.490121
# Bootstrap sampling for general XGBoost: 100%|██████████| 100/100 [00:01<00:00, 55.62it/s]
# Bootstrap sampling for general Random Forest: 100%|██████████| 100/100 [00:02<00:00, 48.37it/s]
# Bootstrap sampling for general Gradient Boosting: 100%|██████████| 100/100 [00:00<00:00, 159.60it/s]
# Processing EDOs: 100%|██████████| 33/33 [01:58<00:00,  3.58s/it]
# XGBoost general predictions for the next period:
#      MORENA  PRIANPRD     OTROS
# 0  0.526353   0.40496  0.067281
# 95% Confidence Intervals for XGBoost:
# Lower - MORENA: 0.5131, PRIANPRD: 0.3878, OTROS: 0.0612
# Upper - MORENA: 0.5401, PRIANPRD: 0.4188, OTROS: 0.0731
#
# Random Forest general predictions for the next period:
#      MORENA  PRIANPRD     OTROS
# 0  0.525293  0.407392  0.065058
# 95% Confidence Intervals for Random Forest:
# Lower - MORENA: 0.5107, PRIANPRD: 0.3945, OTROS: 0.0595
# Upper - MORENA: 0.5386, PRIANPRD: 0.4191, OTROS: 0.0702
#
# Gradient Boosting general predictions for the next period:
#     MORENA  PRIANPRD     OTROS
# 0  0.52713  0.404455  0.066871
# 95% Confidence Intervals for Gradient Boosting:
# Lower - MORENA: 0.5191, PRIANPRD: 0.3946, OTROS: 0.0607
# Upper - MORENA: 0.5373, PRIANPRD: 0.4164, OTROS: 0.0716
#
# XGBoost predictions per EDO for the next period:
#       MORENA  PRIANPRD     OTROS
# 1   0.592179  0.323669  0.081491
# 2   0.588066  0.305025  0.081491
# 3   0.586189  0.323622  0.081491
# 4   0.592694  0.244179  0.109920
# 5   0.598976  0.308611  0.100076
# 6   0.565379  0.357313  0.080791
# 7   0.592179  0.323669  0.081491
# 8   0.593558  0.316614  0.080764
# 9   0.607200  0.313067  0.107235
# 10  0.560021  0.344113  0.084826
# 11  0.581584  0.340967  0.081491
# 12  0.572888  0.346495  0.082672
# 13  0.582733  0.327145  0.080675
# 14  0.622552  0.317932  0.078776
# 15  0.545390  0.309532  0.235959
# 16  0.596348  0.315049  0.085618
# 17  0.589725  0.323244  0.080875
# 18  0.573838  0.240195  0.182730
# 19  0.585640  0.323307  0.091216
# 20  0.592179  0.316640  0.081491
# 21  0.596474  0.324478  0.085111
# 22  0.592179  0.323669  0.087388
# 23  0.591267  0.324154  0.080974
# 24  0.603363  0.239117  0.091145
# 25  0.602361  0.313900  0.076758
# 26  0.606385  0.317003  0.079399
# 27  0.596496  0.320040  0.077872
# 28  0.596592  0.330433  0.080799
# 29  0.577713  0.281515  0.097839
# 30  0.592179  0.298271  0.109740
# 31  0.513950  0.362054  0.086153
# 32  0.592179  0.323669  0.081491
# 99  0.592179  0.323669  0.081491
# 95% Confidence Intervals for XGBoost:
# 1: Lower - MORENA: 0.5922, PRIANPRD: 0.3237, OTROS: 0.0815
#        Upper - MORENA: 0.5922, PRIANPRD: 0.3237, OTROS: 0.0815
# 2: Lower - MORENA: 0.5881, PRIANPRD: 0.3050, OTROS: 0.0815
#        Upper - MORENA: 0.5881, PRIANPRD: 0.3050, OTROS: 0.0815
# 3: Lower - MORENA: 0.5862, PRIANPRD: 0.3236, OTROS: 0.0815
#        Upper - MORENA: 0.5862, PRIANPRD: 0.3236, OTROS: 0.0815
# 4: Lower - MORENA: 0.5927, PRIANPRD: 0.2442, OTROS: 0.1099
#        Upper - MORENA: 0.5927, PRIANPRD: 0.2442, OTROS: 0.1099
# 5: Lower - MORENA: 0.5990, PRIANPRD: 0.3086, OTROS: 0.1001
#        Upper - MORENA: 0.5990, PRIANPRD: 0.3086, OTROS: 0.1001
# 6: Lower - MORENA: 0.5654, PRIANPRD: 0.3573, OTROS: 0.0808
#        Upper - MORENA: 0.5654, PRIANPRD: 0.3573, OTROS: 0.0808
# 7: Lower - MORENA: 0.5922, PRIANPRD: 0.3237, OTROS: 0.0815
#        Upper - MORENA: 0.5922, PRIANPRD: 0.3237, OTROS: 0.0815
# 8: Lower - MORENA: 0.5936, PRIANPRD: 0.3166, OTROS: 0.0808
#        Upper - MORENA: 0.5936, PRIANPRD: 0.3166, OTROS: 0.0808
# 9: Lower - MORENA: 0.6072, PRIANPRD: 0.3131, OTROS: 0.1072
#        Upper - MORENA: 0.6072, PRIANPRD: 0.3131, OTROS: 0.1072
# 10: Lower - MORENA: 0.5600, PRIANPRD: 0.3441, OTROS: 0.0848
#        Upper - MORENA: 0.5600, PRIANPRD: 0.3441, OTROS: 0.0848
# 11: Lower - MORENA: 0.5816, PRIANPRD: 0.3410, OTROS: 0.0815
#        Upper - MORENA: 0.5816, PRIANPRD: 0.3410, OTROS: 0.0815
# 12: Lower - MORENA: 0.5729, PRIANPRD: 0.3465, OTROS: 0.0827
#        Upper - MORENA: 0.5729, PRIANPRD: 0.3465, OTROS: 0.0827
# 13: Lower - MORENA: 0.5827, PRIANPRD: 0.3271, OTROS: 0.0807
#        Upper - MORENA: 0.5827, PRIANPRD: 0.3271, OTROS: 0.0807
# 14: Lower - MORENA: 0.6226, PRIANPRD: 0.3179, OTROS: 0.0788
#        Upper - MORENA: 0.6226, PRIANPRD: 0.3179, OTROS: 0.0788
# 15: Lower - MORENA: 0.5454, PRIANPRD: 0.3095, OTROS: 0.2360
#        Upper - MORENA: 0.5454, PRIANPRD: 0.3095, OTROS: 0.2360
# 16: Lower - MORENA: 0.5963, PRIANPRD: 0.3150, OTROS: 0.0856
#        Upper - MORENA: 0.5963, PRIANPRD: 0.3150, OTROS: 0.0856
# 17: Lower - MORENA: 0.5897, PRIANPRD: 0.3232, OTROS: 0.0809
#        Upper - MORENA: 0.5897, PRIANPRD: 0.3232, OTROS: 0.0809
# 18: Lower - MORENA: 0.5738, PRIANPRD: 0.2402, OTROS: 0.1827
#        Upper - MORENA: 0.5738, PRIANPRD: 0.2402, OTROS: 0.1827
# 19: Lower - MORENA: 0.5856, PRIANPRD: 0.3233, OTROS: 0.0912
#        Upper - MORENA: 0.5856, PRIANPRD: 0.3233, OTROS: 0.0912
# 20: Lower - MORENA: 0.5922, PRIANPRD: 0.3166, OTROS: 0.0815
#        Upper - MORENA: 0.5922, PRIANPRD: 0.3166, OTROS: 0.0815
# 21: Lower - MORENA: 0.5965, PRIANPRD: 0.3245, OTROS: 0.0851
#        Upper - MORENA: 0.5965, PRIANPRD: 0.3245, OTROS: 0.0851
# 22: Lower - MORENA: 0.5922, PRIANPRD: 0.3237, OTROS: 0.0874
#        Upper - MORENA: 0.5922, PRIANPRD: 0.3237, OTROS: 0.0874
# 23: Lower - MORENA: 0.5913, PRIANPRD: 0.3242, OTROS: 0.0810
#        Upper - MORENA: 0.5913, PRIANPRD: 0.3242, OTROS: 0.0810
# 24: Lower - MORENA: 0.6034, PRIANPRD: 0.2391, OTROS: 0.0911
#        Upper - MORENA: 0.6034, PRIANPRD: 0.2391, OTROS: 0.0911
# 25: Lower - MORENA: 0.6024, PRIANPRD: 0.3139, OTROS: 0.0768
#        Upper - MORENA: 0.6024, PRIANPRD: 0.3139, OTROS: 0.0768
# 26: Lower - MORENA: 0.6064, PRIANPRD: 0.3170, OTROS: 0.0794
#        Upper - MORENA: 0.6064, PRIANPRD: 0.3170, OTROS: 0.0794
# 27: Lower - MORENA: 0.5965, PRIANPRD: 0.3200, OTROS: 0.0779
#        Upper - MORENA: 0.5965, PRIANPRD: 0.3200, OTROS: 0.0779
# 28: Lower - MORENA: 0.5966, PRIANPRD: 0.3304, OTROS: 0.0808
#        Upper - MORENA: 0.5966, PRIANPRD: 0.3304, OTROS: 0.0808
# 29: Lower - MORENA: 0.5777, PRIANPRD: 0.2815, OTROS: 0.0978
#        Upper - MORENA: 0.5777, PRIANPRD: 0.2815, OTROS: 0.0978
# 30: Lower - MORENA: 0.5922, PRIANPRD: 0.2983, OTROS: 0.1097
#        Upper - MORENA: 0.5922, PRIANPRD: 0.2983, OTROS: 0.1097
# 31: Lower - MORENA: 0.5140, PRIANPRD: 0.3621, OTROS: 0.0862
#        Upper - MORENA: 0.5140, PRIANPRD: 0.3621, OTROS: 0.0862
# 32: Lower - MORENA: 0.5922, PRIANPRD: 0.3237, OTROS: 0.0815
#        Upper - MORENA: 0.5922, PRIANPRD: 0.3237, OTROS: 0.0815
# 99: Lower - MORENA: 0.5922, PRIANPRD: 0.3237, OTROS: 0.0815
#        Upper - MORENA: 0.5922, PRIANPRD: 0.3237, OTROS: 0.0815
#
# Random Forest predictions per EDO for the next period:
#       MORENA  PRIANPRD     OTROS
# 1   0.585230  0.304842  0.101967
# 2   0.585230  0.276957  0.127409
# 3   0.585230  0.304842  0.101971
# 4   0.585230  0.304842  0.104453
# 5   0.596474  0.285804  0.102869
# 6   0.585230  0.313288  0.101215
# 7   0.585230  0.304842  0.101967
# 8   0.585230  0.304842  0.101967
# 9   0.585230  0.304842  0.131648
# 10  0.585230  0.324821  0.105502
# 11  0.585230  0.304842  0.101967
# 12  0.579598  0.314394  0.095502
# 13  0.572093  0.305977  0.101967
# 14  0.585230  0.309486  0.099804
# 15  0.585230  0.304709  0.251998
# 16  0.585230  0.305691  0.100177
# 17  0.585230  0.304276  0.172368
# 18  0.585230  0.304842  0.166346
# 19  0.585230  0.307572  0.143481
# 20  0.584806  0.303727  0.101988
# 21  0.585230  0.304842  0.104524
# 22  0.585230  0.307826  0.101448
# 23  0.585230  0.303418  0.112053
# 24  0.585230  0.304842  0.103098
# 25  0.585230  0.306355  0.102679
# 26  0.585230  0.305695  0.092347
# 27  0.587519  0.303909  0.102412
# 28  0.585230  0.306465  0.101780
# 29  0.585230  0.304842  0.101967
# 30  0.585230  0.304842  0.105651
# 31  0.585230  0.307970  0.101967
# 32  0.585230  0.304842  0.101967
# 99  0.581341  0.313703  0.094336
# 95% Confidence Intervals for Random Forest:
# 1: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
# 2: Lower - MORENA: 0.5852, PRIANPRD: 0.2770, OTROS: 0.1274
#        Upper - MORENA: 0.5852, PRIANPRD: 0.2770, OTROS: 0.1274
# 3: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
# 4: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1045
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1045
# 5: Lower - MORENA: 0.5965, PRIANPRD: 0.2858, OTROS: 0.1029
#        Upper - MORENA: 0.5965, PRIANPRD: 0.2858, OTROS: 0.1029
# 6: Lower - MORENA: 0.5852, PRIANPRD: 0.3133, OTROS: 0.1012
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3133, OTROS: 0.1012
# 7: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
# 8: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
# 9: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1316
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1316
# 10: Lower - MORENA: 0.5852, PRIANPRD: 0.3248, OTROS: 0.1055
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3248, OTROS: 0.1055
# 11: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
# 12: Lower - MORENA: 0.5796, PRIANPRD: 0.3144, OTROS: 0.0955
#        Upper - MORENA: 0.5796, PRIANPRD: 0.3144, OTROS: 0.0955
# 13: Lower - MORENA: 0.5721, PRIANPRD: 0.3060, OTROS: 0.1020
#        Upper - MORENA: 0.5721, PRIANPRD: 0.3060, OTROS: 0.1020
# 14: Lower - MORENA: 0.5852, PRIANPRD: 0.3095, OTROS: 0.0998
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3095, OTROS: 0.0998
# 15: Lower - MORENA: 0.5852, PRIANPRD: 0.3047, OTROS: 0.2520
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3047, OTROS: 0.2520
# 16: Lower - MORENA: 0.5852, PRIANPRD: 0.3057, OTROS: 0.1002
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3057, OTROS: 0.1002
# 17: Lower - MORENA: 0.5852, PRIANPRD: 0.3043, OTROS: 0.1724
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3043, OTROS: 0.1724
# 18: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1663
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1663
# 19: Lower - MORENA: 0.5852, PRIANPRD: 0.3076, OTROS: 0.1435
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3076, OTROS: 0.1435
# 20: Lower - MORENA: 0.5848, PRIANPRD: 0.3037, OTROS: 0.1020
#        Upper - MORENA: 0.5848, PRIANPRD: 0.3037, OTROS: 0.1020
# 21: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1045
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1045
# 22: Lower - MORENA: 0.5852, PRIANPRD: 0.3078, OTROS: 0.1014
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3078, OTROS: 0.1014
# 23: Lower - MORENA: 0.5852, PRIANPRD: 0.3034, OTROS: 0.1121
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3034, OTROS: 0.1121
# 24: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1031
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1031
# 25: Lower - MORENA: 0.5852, PRIANPRD: 0.3064, OTROS: 0.1027
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3064, OTROS: 0.1027
# 26: Lower - MORENA: 0.5852, PRIANPRD: 0.3057, OTROS: 0.0923
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3057, OTROS: 0.0923
# 27: Lower - MORENA: 0.5875, PRIANPRD: 0.3039, OTROS: 0.1024
#        Upper - MORENA: 0.5875, PRIANPRD: 0.3039, OTROS: 0.1024
# 28: Lower - MORENA: 0.5852, PRIANPRD: 0.3065, OTROS: 0.1018
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3065, OTROS: 0.1018
# 29: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
# 30: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1057
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1057
# 31: Lower - MORENA: 0.5852, PRIANPRD: 0.3080, OTROS: 0.1020
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3080, OTROS: 0.1020
# 32: Lower - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
#        Upper - MORENA: 0.5852, PRIANPRD: 0.3048, OTROS: 0.1020
# 99: Lower - MORENA: 0.5813, PRIANPRD: 0.3137, OTROS: 0.0943
#        Upper - MORENA: 0.5813, PRIANPRD: 0.3137, OTROS: 0.0943
#
# Gradient Boosting predictions per EDO for the next period:
#       MORENA  PRIANPRD     OTROS
# 1   0.567864  0.326258  0.084822
# 2   0.567358  0.302645  0.133982
# 3   0.567864  0.329496  0.084822
# 4   0.555299  0.326258  0.182395
# 5   0.567864  0.324061  0.143384
# 6   0.493640  0.389055  0.084088
# 7   0.567864  0.326258  0.084822
# 8   0.567864  0.326258  0.084822
# 9   0.576607  0.326258  0.160110
# 10  0.543080  0.385029  0.090750
# 11  0.562096  0.341537  0.084822
# 12  0.467386  0.394443  0.064510
# 13  0.549504  0.326258  0.084822
# 14  0.590124  0.315657  0.081302
# 15  0.443708  0.294857  0.271654
# 16  0.567864  0.329978  0.092221
# 17  0.562814  0.279589  0.167657
# 18  0.580292  0.197474  0.183235
# 19  0.541902  0.342096  0.137552
# 20  0.567864  0.298821  0.084822
# 21  0.567864  0.326258  0.095888
# 22  0.567864  0.326258  0.084822
# 23  0.569373  0.321125  0.090833
# 24  0.579889  0.281257  0.114226
# 25  0.588998  0.315071  0.084822
# 26  0.611609  0.308854  0.094534
# 27  0.636843  0.312549  0.084822
# 28  0.553730  0.346077  0.084822
# 29  0.559389  0.261273  0.148994
# 30  0.567864  0.326258  0.153463
# 31  0.428576  0.373707  0.092301
# 32  0.565824  0.326258  0.084822
# 99  0.567864  0.326258  0.084822
# 95% Confidence Intervals for Gradient Boosting:
# 1: Lower - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0848
#        Upper - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0848
# 2: Lower - MORENA: 0.5674, PRIANPRD: 0.3026, OTROS: 0.1340
#        Upper - MORENA: 0.5674, PRIANPRD: 0.3026, OTROS: 0.1340
# 3: Lower - MORENA: 0.5679, PRIANPRD: 0.3295, OTROS: 0.0848
#        Upper - MORENA: 0.5679, PRIANPRD: 0.3295, OTROS: 0.0848
# 4: Lower - MORENA: 0.5553, PRIANPRD: 0.3263, OTROS: 0.1824
#        Upper - MORENA: 0.5553, PRIANPRD: 0.3263, OTROS: 0.1824
# 5: Lower - MORENA: 0.5679, PRIANPRD: 0.3241, OTROS: 0.1434
#        Upper - MORENA: 0.5679, PRIANPRD: 0.3241, OTROS: 0.1434
# 6: Lower - MORENA: 0.4936, PRIANPRD: 0.3891, OTROS: 0.0841
#        Upper - MORENA: 0.4936, PRIANPRD: 0.3891, OTROS: 0.0841
# 7: Lower - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0848
#        Upper - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0848
# 8: Lower - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0848
#        Upper - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0848
# 9: Lower - MORENA: 0.5766, PRIANPRD: 0.3263, OTROS: 0.1601
#        Upper - MORENA: 0.5766, PRIANPRD: 0.3263, OTROS: 0.1601
# 10: Lower - MORENA: 0.5431, PRIANPRD: 0.3850, OTROS: 0.0908
#        Upper - MORENA: 0.5431, PRIANPRD: 0.3850, OTROS: 0.0908
# 11: Lower - MORENA: 0.5621, PRIANPRD: 0.3415, OTROS: 0.0848
#        Upper - MORENA: 0.5621, PRIANPRD: 0.3415, OTROS: 0.0848
# 12: Lower - MORENA: 0.4674, PRIANPRD: 0.3944, OTROS: 0.0645
#        Upper - MORENA: 0.4674, PRIANPRD: 0.3944, OTROS: 0.0645
# 13: Lower - MORENA: 0.5495, PRIANPRD: 0.3263, OTROS: 0.0848
#        Upper - MORENA: 0.5495, PRIANPRD: 0.3263, OTROS: 0.0848
# 14: Lower - MORENA: 0.5901, PRIANPRD: 0.3157, OTROS: 0.0813
#        Upper - MORENA: 0.5901, PRIANPRD: 0.3157, OTROS: 0.0813
# 15: Lower - MORENA: 0.4437, PRIANPRD: 0.2949, OTROS: 0.2717
#        Upper - MORENA: 0.4437, PRIANPRD: 0.2949, OTROS: 0.2717
# 16: Lower - MORENA: 0.5679, PRIANPRD: 0.3300, OTROS: 0.0922
#        Upper - MORENA: 0.5679, PRIANPRD: 0.3300, OTROS: 0.0922
# 17: Lower - MORENA: 0.5628, PRIANPRD: 0.2796, OTROS: 0.1677
#        Upper - MORENA: 0.5628, PRIANPRD: 0.2796, OTROS: 0.1677
# 18: Lower - MORENA: 0.5803, PRIANPRD: 0.1975, OTROS: 0.1832
#        Upper - MORENA: 0.5803, PRIANPRD: 0.1975, OTROS: 0.1832
# 19: Lower - MORENA: 0.5419, PRIANPRD: 0.3421, OTROS: 0.1376
#        Upper - MORENA: 0.5419, PRIANPRD: 0.3421, OTROS: 0.1376
# 20: Lower - MORENA: 0.5679, PRIANPRD: 0.2988, OTROS: 0.0848
#        Upper - MORENA: 0.5679, PRIANPRD: 0.2988, OTROS: 0.0848
# 21: Lower - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0959
#        Upper - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0959
# 22: Lower - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0848
#        Upper - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0848
# 23: Lower - MORENA: 0.5694, PRIANPRD: 0.3211, OTROS: 0.0908
#        Upper - MORENA: 0.5694, PRIANPRD: 0.3211, OTROS: 0.0908
# 24: Lower - MORENA: 0.5799, PRIANPRD: 0.2813, OTROS: 0.1142
#        Upper - MORENA: 0.5799, PRIANPRD: 0.2813, OTROS: 0.1142
# 25: Lower - MORENA: 0.5890, PRIANPRD: 0.3151, OTROS: 0.0848
#        Upper - MORENA: 0.5890, PRIANPRD: 0.3151, OTROS: 0.0848
# 26: Lower - MORENA: 0.6116, PRIANPRD: 0.3089, OTROS: 0.0945
#        Upper - MORENA: 0.6116, PRIANPRD: 0.3089, OTROS: 0.0945
# 27: Lower - MORENA: 0.6368, PRIANPRD: 0.3125, OTROS: 0.0848
#        Upper - MORENA: 0.6368, PRIANPRD: 0.3125, OTROS: 0.0848
# 28: Lower - MORENA: 0.5537, PRIANPRD: 0.3461, OTROS: 0.0848
#        Upper - MORENA: 0.5537, PRIANPRD: 0.3461, OTROS: 0.0848
# 29: Lower - MORENA: 0.5594, PRIANPRD: 0.2613, OTROS: 0.1490
#        Upper - MORENA: 0.5594, PRIANPRD: 0.2613, OTROS: 0.1490
# 30: Lower - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.1535
#        Upper - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.1535
# 31: Lower - MORENA: 0.4286, PRIANPRD: 0.3737, OTROS: 0.0923
#        Upper - MORENA: 0.4286, PRIANPRD: 0.3737, OTROS: 0.0923
# 32: Lower - MORENA: 0.5658, PRIANPRD: 0.3263, OTROS: 0.0848
#        Upper - MORENA: 0.5658, PRIANPRD: 0.3263, OTROS: 0.0848
# 99: Lower - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0848
#        Upper - MORENA: 0.5679, PRIANPRD: 0.3263, OTROS: 0.0848
# Total execution time: 122.67 seconds
