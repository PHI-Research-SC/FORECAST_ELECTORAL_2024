# %%
import pandas as pd
#Load file
df = pd.read_excel('/content/Base_FINAL.xlsx')

# %%
# Filters
df = df[(df['AÑO'] >= 2018) & (~df['TIPO'].isin(['EST', 'OTRAS']))]

# %%
import time
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error
from sklearn.utils import resample
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# Ensure the data is in numpy array format and correct dtype
X_features = df.drop(columns=['TIPO', 'AÑO', 'MORENA', 'PRIANPRD', 'OTROS'])
y = df[['MORENA', 'PRIANPRD', 'OTROS']]

# Convert categorical 'EDO' column to numeric using one-hot encoding without dropping first level
X_features = pd.get_dummies(X_features, columns=['EDO']).values.astype(np.float32)
y = y.values.astype(np.float32)

# Verify the data types
print(f"X_features dtype: {X_features.dtype}")
print(f"y dtype: {y.dtype}")

# Define function to calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred, threshold=1e-2):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    mask = y_true > threshold
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

# Define and train the Sequential Neural Network model
def build_sequential_nn(input_shape):
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=input_shape))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(3, activation='linear'))
    model.compile(optimizer='adam', loss='mse')
    return model

# Define and train the LSTM model
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=(1, input_shape)))
    model.add(Dense(3, activation='linear'))
    model.compile(optimizer='adam', loss='mse')
    return model

# Train and evaluate models
input_shape = (X_features.shape[1],)
X_features_reshaped = X_features.reshape((X_features.shape[0], 1, X_features.shape[1]))

models = {
    'Sequential_NN': build_sequential_nn(input_shape),
    'LSTM': build_lstm_model(X_features.shape[1])
}

trained_models = {}
mse_scores = {}
mae_scores = {}
mape_scores = {}

# Training models
for name, model in models.items():
    if name == 'LSTM':
        model.fit(X_features_reshaped, y, epochs=50, batch_size=32, verbose=0)
    else:
        model.fit(X_features, y, epochs=50, batch_size=32, verbose=0)

    preds = model.predict(X_features if name != 'LSTM' else X_features_reshaped)
    mse_scores[name] = mean_squared_error(y, preds)
    mae_scores[name] = mean_absolute_error(y, preds)
    mape_scores[name] = mean_absolute_percentage_error(y, preds)
    trained_models[name] = model

# Select the models for predictions
selected_models = ['Sequential_NN', 'LSTM']

# Create a DataFrame to display the errors of the selected models
errors_df = pd.DataFrame(
    [(model, mse_scores[model], mae_scores[model], mape_scores[model]) for model in selected_models],
    columns=['Model', 'MSE', 'MAE', 'MAPE']
)

# Display the DataFrame with the selected models and their errors
print("Selected Models with Errors:")
print(errors_df)

# Timing the process
start_time = time.time()

# Initialize dictionary to store predictions per EDO
predictions_per_edo = {}
ci_per_edo = {}

# Get unique labels in the 'EDO' column
unique_edos = df['EDO'].unique()

# Ensure the one-hot encoded columns exist
encoded_columns = [f'EDO_{edo}' for edo in unique_edos]
encoded_columns_in_df = [col for col in encoded_columns if col in df.columns]

# Number of bootstrap samples
n_bootstrap_samples = 100  # Reduced to 100 for faster computation

# General prediction
general_predictions = {}
general_ci = {}

# Calculate general predictions and confidence intervals
for name in selected_models:
    model = trained_models[name]
    preds_samples = []

    for _ in tqdm(range(n_bootstrap_samples), desc=f"Bootstrap sampling for general {name}"):
        X_resampled = resample(X_features).astype(np.float32)
        if name == 'LSTM':
            X_resampled = X_resampled.reshape((X_resampled.shape[0], 1, X_resampled.shape[1]))
        preds_resampled = model.predict(X_resampled)
        preds_samples.append(preds_resampled.mean(axis=0))

    preds_samples = np.array(preds_samples)
    preds_mean = preds_samples.mean(axis=0)
    preds_lower = np.percentile(preds_samples, 2.5, axis=0)
    preds_upper = np.percentile(preds_samples, 97.5, axis=0)

    general_predictions[name] = preds_mean
    general_ci[name] = (preds_lower, preds_upper)

# Iterate over each unique 'EDO' label
for edo in tqdm(unique_edos, desc="Processing EDOs"):
    # Create a dummy data point for prediction for the given EDO
    X_new_period_edo = X_features.mean(axis=0).reshape((1, -1)).astype(np.float32)

    # Check if the one-hot encoded column for this EDO exists
    col_name = f'EDO_{edo}'
    if col_name in encoded_columns_in_df:
        col_index = df.columns.get_loc(col_name)
        X_new_period_edo[0, col_index] = 1  # Add one-hot encoded EDO column

    # Ensure the new period data has the same columns as the training set
    X_new_period_edo_reshaped = X_new_period_edo.reshape((X_new_period_edo.shape[0], 1, X_new_period_edo.shape[1]))

    # Store predictions and confidence intervals for the selected models
    for name in selected_models:
        model = trained_models[name]

        # Bootstrap sampling to calculate confidence intervals
        preds_samples = []
        for _ in range(n_bootstrap_samples):
            preds_resampled = model.predict(X_new_period_edo if name != 'LSTM' else X_new_period_edo_reshaped)
            preds_samples.append(preds_resampled.flatten())

        preds_samples = np.array(preds_samples)
        preds_mean = preds_samples.mean(axis=0)
        preds_lower = np.percentile(preds_samples, 2.5, axis=0)
        preds_upper = np.percentile(preds_samples, 97.5, axis=0)

        predictions_per_edo.setdefault(name, []).append(preds_mean)
        ci_per_edo.setdefault(name, []).append((preds_lower, preds_upper))

# Timing end
end_time = time.time()
total_time = end_time - start_time

# Convert general predictions to DataFrames and add labels
general_predictions_df = {name: pd.DataFrame([preds], columns=['MORENA', 'PRIANPRD', 'OTROS']) for name, preds in general_predictions.items()}

# Convert EDO predictions to DataFrames and add labels
predictions_df_per_edo = {name: pd.DataFrame(preds, index=unique_edos, columns=['MORENA', 'PRIANPRD', 'OTROS']) for name, preds in predictions_per_edo.items()}

# Display the general predictions and confidence intervals
for name, df in general_predictions_df.items():
    print(f"\n{name} general predictions for the next period:")
    print(df)
    lower_ci = general_ci[name][0]
    upper_ci = general_ci[name][1]
    print(f"95% Confidence Intervals for {name}:")
    print(f"Lower - MORENA: {lower_ci[0]:.4f}, PRIANPRD: {lower_ci[1]:.4f}, OTROS: {lower_ci[2]:.4f}")
    print(f"Upper - MORENA: {upper_ci[0]:.4f}, PRIANPRD: {upper_ci[1]:.4f}, OTROS: {upper_ci[2]:.4f}")

# Display the DataFrames with EDO predictions and confidence intervals
for name, df in predictions_df_per_edo.items():
    print(f"\n{name} predictions per EDO for the next period:")
    print(df)
    print(f"95% Confidence Intervals for {name}:")
    for i, edo in enumerate(unique_edos):
        lower_ci = ci_per_edo[name][i][0]
        upper_ci = ci_per_edo[name][i][1]
        print(f"{edo}: Lower - MORENA: {lower_ci[0]:.4f}, PRIANPRD: {lower_ci[1]:.4f}, OTROS: {lower_ci[2]:.4f}")
        print(f"       Upper - MORENA: {upper_ci[0]:.4f}, PRIANPRD: {upper_ci[1]:.4f}, OTROS: {upper_ci[2]:.4f}")

print(f"Total execution time: {total_time:.2f} seconds")
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# X_features dtype: float32
# y dtype: float32
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Selected Models with Errors:
#            Model       MSE       MAE       MAPE
# 0  Sequential_NN  0.004148  0.049625  24.513263
# 1           LSTM  0.004266  0.050149  24.223070
# Bootstrap sampling for general Sequential_NN:   0%|          | 0/100 [00:00<?, ?it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:   2%|▏         | 2/100 [00:00<00:07, 13.34it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:   4%|▍         | 4/100 [00:00<00:07, 13.56it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:   6%|▌         | 6/100 [00:00<00:06, 13.79it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:   8%|▊         | 8/100 [00:00<00:06, 13.85it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  10%|█         | 10/100 [00:00<00:06, 13.10it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  12%|█▏        | 12/100 [00:00<00:06, 13.39it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  14%|█▍        | 14/100 [00:01<00:06, 13.60it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  16%|█▌        | 16/100 [00:01<00:06, 13.58it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  18%|█▊        | 18/100 [00:01<00:06, 13.48it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  20%|██        | 20/100 [00:01<00:05, 13.64it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  22%|██▏       | 22/100 [00:01<00:05, 13.52it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  24%|██▍       | 24/100 [00:01<00:05, 13.33it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  26%|██▌       | 26/100 [00:01<00:05, 13.43it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  28%|██▊       | 28/100 [00:02<00:05, 13.11it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  30%|███       | 30/100 [00:02<00:05, 13.15it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  32%|███▏      | 32/100 [00:02<00:05, 13.34it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  34%|███▍      | 34/100 [00:02<00:04, 13.42it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  36%|███▌      | 36/100 [00:02<00:04, 13.28it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  38%|███▊      | 38/100 [00:02<00:04, 13.23it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  40%|████      | 40/100 [00:02<00:04, 13.33it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  42%|████▏     | 42/100 [00:03<00:04, 13.17it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  44%|████▍     | 44/100 [00:03<00:04, 12.72it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  46%|████▌     | 46/100 [00:03<00:04, 12.73it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  48%|████▊     | 48/100 [00:03<00:04, 12.82it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  50%|█████     | 50/100 [00:03<00:03, 13.06it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  52%|█████▏    | 52/100 [00:03<00:03, 13.26it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  54%|█████▍    | 54/100 [00:04<00:03, 13.11it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  56%|█████▌    | 56/100 [00:04<00:03, 13.26it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  58%|█████▊    | 58/100 [00:04<00:03, 13.40it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  60%|██████    | 60/100 [00:04<00:02, 13.39it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  62%|██████▏   | 62/100 [00:04<00:02, 13.48it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  64%|██████▍   | 64/100 [00:04<00:02, 13.47it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  66%|██████▌   | 66/100 [00:04<00:02, 13.51it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  68%|██████▊   | 68/100 [00:05<00:02, 13.41it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  70%|███████   | 70/100 [00:05<00:02, 13.44it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  72%|███████▏  | 72/100 [00:05<00:02, 13.34it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  74%|███████▍  | 74/100 [00:05<00:01, 13.28it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  76%|███████▌  | 76/100 [00:05<00:01, 13.35it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  78%|███████▊  | 78/100 [00:05<00:01, 13.14it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  80%|████████  | 80/100 [00:06<00:01, 13.14it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  82%|████████▏ | 82/100 [00:06<00:01, 13.04it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  84%|████████▍ | 84/100 [00:06<00:01, 13.32it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  86%|████████▌ | 86/100 [00:06<00:01, 13.24it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  88%|████████▊ | 88/100 [00:06<00:00, 13.27it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  90%|█████████ | 90/100 [00:06<00:00, 13.24it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  92%|█████████▏| 92/100 [00:06<00:00, 13.25it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  94%|█████████▍| 94/100 [00:07<00:00, 13.22it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  96%|█████████▌| 96/100 [00:07<00:00, 13.39it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  98%|█████████▊| 98/100 [00:07<00:00, 13.57it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN: 100%|██████████| 100/100 [00:07<00:00, 13.30it/s]
# Bootstrap sampling for general LSTM:   0%|          | 0/100 [00:00<?, ?it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:   2%|▏         | 2/100 [00:00<00:07, 13.72it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:   4%|▍         | 4/100 [00:00<00:06, 13.83it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:   6%|▌         | 6/100 [00:00<00:07, 13.21it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:   8%|▊         | 8/100 [00:00<00:07, 13.05it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  10%|█         | 10/100 [00:00<00:06, 13.21it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  12%|█▏        | 12/100 [00:00<00:06, 13.11it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  14%|█▍        | 14/100 [00:01<00:06, 13.16it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  16%|█▌        | 16/100 [00:01<00:06, 13.28it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 3ms/step
# Bootstrap sampling for general LSTM:  18%|█▊        | 18/100 [00:01<00:06, 12.79it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  20%|██        | 20/100 [00:01<00:06, 12.82it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  22%|██▏       | 22/100 [00:01<00:05, 13.00it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  24%|██▍       | 24/100 [00:01<00:05, 13.04it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  26%|██▌       | 26/100 [00:01<00:05, 12.93it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  28%|██▊       | 28/100 [00:02<00:05, 13.14it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  30%|███       | 30/100 [00:02<00:05, 13.28it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  32%|███▏      | 32/100 [00:02<00:05, 12.90it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  34%|███▍      | 34/100 [00:02<00:05, 12.99it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  36%|███▌      | 36/100 [00:02<00:04, 12.94it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  38%|███▊      | 38/100 [00:02<00:04, 12.89it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  40%|████      | 40/100 [00:03<00:04, 13.08it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  42%|████▏     | 42/100 [00:03<00:04, 13.34it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  44%|████▍     | 44/100 [00:03<00:04, 13.17it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  46%|████▌     | 46/100 [00:03<00:04, 13.14it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  48%|████▊     | 48/100 [00:03<00:03, 13.34it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  50%|█████     | 50/100 [00:03<00:03, 13.32it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  52%|█████▏    | 52/100 [00:03<00:03, 13.32it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  54%|█████▍    | 54/100 [00:04<00:03, 13.29it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  56%|█████▌    | 56/100 [00:04<00:03, 13.33it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  58%|█████▊    | 58/100 [00:04<00:03, 13.28it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  60%|██████    | 60/100 [00:04<00:03, 13.15it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  62%|██████▏   | 62/100 [00:04<00:02, 13.20it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  64%|██████▍   | 64/100 [00:04<00:02, 13.15it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  66%|██████▌   | 66/100 [00:05<00:02, 13.26it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  68%|██████▊   | 68/100 [00:05<00:02, 13.48it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  70%|███████   | 70/100 [00:05<00:02, 13.45it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  72%|███████▏  | 72/100 [00:05<00:02, 13.26it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  74%|███████▍  | 74/100 [00:05<00:01, 13.36it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  76%|███████▌  | 76/100 [00:05<00:01, 13.41it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  78%|███████▊  | 78/100 [00:05<00:01, 13.32it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  80%|████████  | 80/100 [00:06<00:01, 13.32it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  82%|████████▏ | 82/100 [00:06<00:01, 13.02it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  84%|████████▍ | 84/100 [00:06<00:01, 12.88it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  86%|████████▌ | 86/100 [00:06<00:01, 13.11it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  88%|████████▊ | 88/100 [00:06<00:00, 13.25it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  90%|█████████ | 90/100 [00:06<00:00, 12.67it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  92%|█████████▏| 92/100 [00:07<00:00, 12.77it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  94%|█████████▍| 94/100 [00:07<00:00, 12.87it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  96%|█████████▌| 96/100 [00:07<00:00, 12.72it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  98%|█████████▊| 98/100 [00:07<00:00, 12.71it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM: 100%|██████████| 100/100 [00:07<00:00, 13.08it/s]
# Processing EDOs:   0%|          | 0/33 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Processing EDOs:   3%|▎         | 1/33 [00:12<06:40, 12.50s/it]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Processing EDOs:   6%|▌         | 2/33 [00:24<06:23, 12.37s/it]
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# ...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Processing EDOs: 100%|██████████| 33/33 [06:54<00:00, 12.57s/it]
# Sequential_NN general predictions for the next period:
#      MORENA  PRIANPRD     OTROS
# 0  0.523954  0.402746  0.070216
# 95% Confidence Intervals for Sequential_NN:
# Lower - MORENA: 0.5080, PRIANPRD: 0.3908, OTROS: 0.0670
# Upper - MORENA: 0.5349, PRIANPRD: 0.4206, OTROS: 0.0732
#
# LSTM general predictions for the next period:
#      MORENA  PRIANPRD     OTROS
# 0  0.526276  0.405451  0.066633
# 95% Confidence Intervals for LSTM:
# Lower - MORENA: 0.5137, PRIANPRD: 0.3903, OTROS: 0.0636
# Upper - MORENA: 0.5394, PRIANPRD: 0.4190, OTROS: 0.0697
#
# Sequential_NN predictions per EDO for the next period:
#       MORENA  PRIANPRD     OTROS
# 1   0.367633  0.362346  0.010018
# 2   0.367633  0.362346  0.010018
# 3   0.367633  0.362346  0.010018
# 4   0.367633  0.362346  0.010018
# 5   0.367633  0.362346  0.010018
# 6   0.367633  0.362346  0.010018
# 7   0.367633  0.362346  0.010018
# 8   0.367633  0.362346  0.010018
# 9   0.367633  0.362346  0.010018
# 10  0.367633  0.362346  0.010018
# 11  0.367633  0.362346  0.010018
# 12  0.367633  0.362346  0.010018
# 13  0.367633  0.362346  0.010018
# 14  0.367633  0.362346  0.010018
# 15  0.367633  0.362346  0.010018
# 16  0.367633  0.362346  0.010018
# 17  0.367633  0.362346  0.010018
# 18  0.367633  0.362346  0.010018
# 19  0.367633  0.362346  0.010018
# 20  0.367633  0.362346  0.010018
# 21  0.367633  0.362346  0.010018
# 22  0.367633  0.362346  0.010018
# 23  0.367633  0.362346  0.010018
# 24  0.367633  0.362346  0.010018
# 25  0.367633  0.362346  0.010018
# 26  0.367633  0.362346  0.010018
# 27  0.367633  0.362346  0.010018
# 28  0.367633  0.362346  0.010018
# 29  0.367633  0.362346  0.010018
# 30  0.367633  0.362346  0.010018
# 31  0.367633  0.362346  0.010018
# 32  0.367633  0.362346  0.010018
# 99  0.367633  0.362346  0.010018
# 95% Confidence Intervals for Sequential_NN:
# 1: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 2: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 3: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 4: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 5: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 6: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 7: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 8: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 9: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 10: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 11: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 12: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 13: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 14: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 15: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 16: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 17: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 18: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 19: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 20: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 21: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 22: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 23: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 24: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 25: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 26: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 27: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 28: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 29: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 30: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 31: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 32: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
# 99: Lower - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#        Upper - MORENA: 0.3676, PRIANPRD: 0.3623, OTROS: 0.0100
#
# LSTM predictions per EDO for the next period:
#       MORENA  PRIANPRD     OTROS
# 1   0.495796  0.397609  0.064649
# 2   0.495796  0.397609  0.064649
# 3   0.495796  0.397609  0.064649
# 4   0.495796  0.397609  0.064649
# 5   0.495796  0.397609  0.064649
# 6   0.495796  0.397609  0.064649
# 7   0.495796  0.397609  0.064649
# 8   0.495796  0.397609  0.064649
# 9   0.495796  0.397609  0.064649
# 10  0.495796  0.397609  0.064649
# 11  0.495796  0.397609  0.064649
# 12  0.495796  0.397609  0.064649
# 13  0.495796  0.397609  0.064649
# 14  0.495796  0.397609  0.064649
# 15  0.495796  0.397609  0.064649
# 16  0.495796  0.397609  0.064649
# 17  0.495796  0.397609  0.064649
# 18  0.495796  0.397609  0.064649
# 19  0.495796  0.397609  0.064649
# 20  0.495796  0.397609  0.064649
# 21  0.495796  0.397609  0.064649
# 22  0.495796  0.397609  0.064649
# 23  0.495796  0.397609  0.064649
# 24  0.495796  0.397609  0.064649
# 25  0.495796  0.397609  0.064649
# 26  0.495796  0.397609  0.064649
# 27  0.495796  0.397609  0.064649
# 28  0.495796  0.397609  0.064649
# 29  0.495796  0.397609  0.064649
# 30  0.495796  0.397609  0.064649
# 31  0.495796  0.397609  0.064649
# 32  0.495796  0.397609  0.064649
# 99  0.495796  0.397609  0.064649
# 95% Confidence Intervals for LSTM:
# 1: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 2: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 3: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 4: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 5: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 6: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 7: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 8: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 9: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 10: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 11: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 12: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 13: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 14: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 15: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 16: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 17: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 18: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 19: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 20: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 21: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 22: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 23: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 24: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 25: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 26: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 27: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 28: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 29: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 30: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 31: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 32: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# 99: Lower - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
#        Upper - MORENA: 0.4958, PRIANPRD: 0.3976, OTROS: 0.0646
# Total execution time: 429.97 seconds

# %%
import time
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error
from sklearn.utils import resample
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# Ensure the data is in numpy array format and correct dtype
X_features = df.drop(columns=['TIPO', 'AÑO', 'MORENA', 'PRIANPRD', 'OTROS'])
y = df[['MORENA', 'PRIANPRD', 'OTROS']]

# Convert categorical 'EDO' column to numeric using one-hot encoding without dropping the first level
X_features = pd.get_dummies(X_features, columns=['EDO']).values.astype(np.float32)
y = y.values.astype(np.float32)

# Verify the data types
print(f"X_features dtype: {X_features.dtype}")
print(f"y dtype: {y.dtype}")

# Define function to calculate MAPE
def mean_absolute_percentage_error_custom(y_true, y_pred, threshold=1e-2):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    mask = y_true > threshold
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

# Define and train the Sequential Neural Network model
def build_sequential_nn(input_shape):
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=input_shape))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(3, activation='linear'))
    model.compile(optimizer='adam', loss='mse')
    return model

# Define and train the LSTM model
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=(1, input_shape)))
    model.add(Dense(3, activation='linear'))
    model.compile(optimizer='adam', loss='mse')
    return model

# Train and evaluate models
input_shape = (X_features.shape[1],)
X_features_reshaped = X_features.reshape((X_features.shape[0], 1, X_features.shape[1]))

models = {
    'Sequential_NN': build_sequential_nn(input_shape),
    'LSTM': build_lstm_model(X_features.shape[1])
}

trained_models = {}
mse_scores = {}
mae_scores = {}
mape_scores = {}

# Training models
for name, model in models.items():
    if name == 'LSTM':
        model.fit(X_features_reshaped, y, epochs=50, batch_size=32, verbose=0)
    else:
        model.fit(X_features, y, epochs=50, batch_size=32, verbose=0)

    preds = model.predict(X_features if name != 'LSTM' else X_features_reshaped)
    mse_scores[name] = mean_squared_error(y, preds)
    mae_scores[name] = mean_absolute_error(y, preds)
    mape_scores[name] = mean_absolute_percentage_error_custom(y, preds)
    trained_models[name] = model

# Create a DataFrame to display the errors of the selected models
errors_df = pd.DataFrame(
    [(model, mse_scores[model], mae_scores[model], mape_scores[model]) for model in models.keys()],
    columns=['Model', 'MSE', 'MAE', 'MAPE']
)

# Display the DataFrame with the errors
print("Selected Models with Errors:")
print(errors_df)

# Timing the process
start_time = time.time()

# Initialize dictionary to store predictions per EDO
predictions_per_edo = {}
ci_per_edo = {}

# Get unique labels in the 'EDO' column
unique_edos = df['EDO'].unique()

# Ensure the one-hot encoded columns exist
encoded_columns = [f'EDO_{edo}' for edo in unique_edos]
encoded_columns_in_df = [col for col in encoded_columns if col in df.columns]

# Number of bootstrap samples
n_bootstrap_samples = 100  # Reduced to 100 for faster computation

# General prediction
general_predictions = {}
general_ci = {}

# Calculate general predictions and confidence intervals
for name in models.keys():
    model = trained_models[name]
    preds_samples = []

    for _ in tqdm(range(n_bootstrap_samples), desc=f"Bootstrap sampling for general {name}"):
        X_resampled = resample(X_features).astype(np.float32)
        if name == 'LSTM':
            X_resampled = X_resampled.reshape((X_resampled.shape[0], 1, X_resampled.shape[1]))
        preds_resampled = model.predict(X_resampled)
        preds_samples.append(preds_resampled.mean(axis=0))

    preds_samples = np.array(preds_samples)
    preds_mean = preds_samples.mean(axis=0)
    preds_lower = np.percentile(preds_samples, 2.5, axis=0)
    preds_upper = np.percentile(preds_samples, 97.5, axis=0)

    general_predictions[name] = preds_mean
    general_ci[name] = (preds_lower, preds_upper)

# Iterate over each unique 'EDO' label
for edo in tqdm(unique_edos, desc="Processing EDOs"):
    # Create a dummy data point for prediction for the given EDO
    X_new_period_edo = X_features.mean(axis=0).reshape((1, -1)).astype(np.float32)

    # Check if the one-hot encoded column for this EDO exists
    col_name = f'EDO_{edo}'
    if col_name in encoded_columns_in_df:
        col_index = df.columns.get_loc(col_name)
        X_new_period_edo[0, col_index] = 1  # Add one-hot encoded EDO column

    # Ensure the new period data has the same columns as the training set
    X_new_period_edo_reshaped = X_new_period_edo.reshape((X_new_period_edo.shape[0], 1, X_new_period_edo.shape[1]))

    # Store predictions and confidence intervals for the selected models
    for name in models.keys():
        model = trained_models[name]

        # Bootstrap sampling to calculate confidence intervals
        preds_samples = []
        for _ in range(n_bootstrap_samples):
            preds_resampled = model.predict(X_new_period_edo if name != 'LSTM' else X_new_period_edo_reshaped)
            preds_samples.append(preds_resampled.flatten())

        preds_samples = np.array(preds_samples)
        preds_mean = preds_samples.mean(axis=0)
        preds_lower = np.percentile(preds_samples, 2.5, axis=0)
        preds_upper = np.percentile(preds_samples, 97.5, axis=0)

        predictions_per_edo.setdefault(name, []).append(preds_mean)
        ci_per_edo.setdefault(name, []).append((preds_lower, preds_upper))

# Timing end
end_time = time.time()
total_time = end_time - start_time

# Convert general predictions to DataFrames and add labels
general_predictions_df = {name: pd.DataFrame([preds], columns=['MORENA', 'PRIANPRD', 'OTROS']) for name, preds in general_predictions.items()}

# Convert EDO predictions to DataFrames and add labels
predictions_df_per_edo = {name: pd.DataFrame(preds, index=unique_edos, columns=['MORENA', 'PRIANPRD', 'OTROS']) for name, preds in predictions_per_edo.items()}

# Display the general predictions and confidence intervals
for name, df in general_predictions_df.items():
    print(f"\n{name} general predictions for the next period:")
    print(df)
    lower_ci = general_ci[name][0]
    upper_ci = general_ci[name][1]
    print(f"95% Confidence Intervals for {name}:")
    print(f"Lower - MORENA: {lower_ci[0]:.4f}, PRIANPRD: {lower_ci[1]:.4f}, OTROS: {lower_ci[2]:.4f}")
    print(f"Upper - MORENA: {upper_ci[0]:.4f}, PRIANPRD: {upper_ci[1]:.4f}, OTROS: {upper_ci[2]:.4f}")

# Display the DataFrames with EDO predictions and confidence intervals
for name, df in predictions_df_per_edo.items():
    print(f"\n{name} predictions per EDO for the next period:")
    print(df)
    print(f"95% Confidence Intervals for {name}:")
    for i, edo in enumerate(unique_edos):
        lower_ci = ci_per_edo[name][i][0]
        upper_ci = ci_per_edo[name][i][1]
        print(f"{edo}: Lower - MORENA: {lower_ci[0]:.4f}, PRIANPRD: {lower_ci[1]:.4f}, OTROS: {lower_ci[2]:.4f}")
        print(f"       Upper - MORENA: {upper_ci[0]:.4f}, PRIANPRD: {upper_ci[1]:.4f}, OTROS: {upper_ci[2]:.4f}")

print(f"Total execution time: {total_time:.2f} seconds")
# Out:
# X_features dtype: float32
# y dtype: float32
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Selected Models with Errors:
#            Model       MSE       MAE       MAPE
# 0  Sequential_NN  0.004155  0.049426  24.274854
# 1           LSTM  0.004342  0.050548  24.143195
# Bootstrap sampling for general Sequential_NN:   0%|          | 0/100 [00:00<?, ?it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:   2%|▏         | 2/100 [00:00<00:07, 13.43it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:   4%|▍         | 4/100 [00:00<00:07, 13.15it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:   6%|▌         | 6/100 [00:00<00:06, 13.44it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:   8%|▊         | 8/100 [00:00<00:06, 13.33it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  10%|█         | 10/100 [00:00<00:06, 13.38it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  12%|█▏        | 12/100 [00:00<00:06, 13.31it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  14%|█▍        | 14/100 [00:01<00:06, 13.54it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  16%|█▌        | 16/100 [00:01<00:06, 13.07it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  18%|█▊        | 18/100 [00:01<00:06, 13.21it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  20%|██        | 20/100 [00:01<00:05, 13.38it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  22%|██▏       | 22/100 [00:01<00:05, 13.53it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  24%|██▍       | 24/100 [00:01<00:05, 13.63it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  26%|██▌       | 26/100 [00:01<00:05, 13.36it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  28%|██▊       | 28/100 [00:02<00:05, 13.58it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  30%|███       | 30/100 [00:02<00:05, 13.32it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  32%|███▏      | 32/100 [00:02<00:05, 13.50it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  34%|███▍      | 34/100 [00:02<00:04, 13.68it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  36%|███▌      | 36/100 [00:02<00:04, 13.53it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  38%|███▊      | 38/100 [00:02<00:04, 13.45it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  40%|████      | 40/100 [00:02<00:04, 13.42it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  42%|████▏     | 42/100 [00:03<00:04, 13.44it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  44%|████▍     | 44/100 [00:03<00:04, 13.35it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  46%|████▌     | 46/100 [00:03<00:04, 13.33it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  48%|████▊     | 48/100 [00:03<00:03, 13.11it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  50%|█████     | 50/100 [00:03<00:03, 13.12it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  52%|█████▏    | 52/100 [00:03<00:03, 13.25it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  54%|█████▍    | 54/100 [00:04<00:03, 13.28it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  56%|█████▌    | 56/100 [00:04<00:03, 13.17it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  58%|█████▊    | 58/100 [00:04<00:03, 12.67it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  60%|██████    | 60/100 [00:04<00:03, 12.98it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  62%|██████▏   | 62/100 [00:04<00:02, 13.02it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  64%|██████▍   | 64/100 [00:04<00:02, 13.30it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  66%|██████▌   | 66/100 [00:04<00:02, 13.44it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  68%|██████▊   | 68/100 [00:05<00:02, 13.42it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  70%|███████   | 70/100 [00:05<00:02, 13.39it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  72%|███████▏  | 72/100 [00:05<00:02, 13.33it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  74%|███████▍  | 74/100 [00:05<00:01, 13.44it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  76%|███████▌  | 76/100 [00:05<00:01, 13.29it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  78%|███████▊  | 78/100 [00:05<00:01, 13.60it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  80%|████████  | 80/100 [00:05<00:01, 13.83it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  82%|████████▏ | 82/100 [00:06<00:01, 13.74it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  84%|████████▍ | 84/100 [00:06<00:01, 13.59it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  86%|████████▌ | 86/100 [00:06<00:01, 13.37it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  88%|████████▊ | 88/100 [00:06<00:00, 13.42it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  90%|█████████ | 90/100 [00:06<00:00, 13.58it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  92%|█████████▏| 92/100 [00:06<00:00, 13.81it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  94%|█████████▍| 94/100 [00:07<00:00, 13.64it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN:  96%|█████████▌| 96/100 [00:07<00:00, 13.62it/s]
# 7/7 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general Sequential_NN:  98%|█████████▊| 98/100 [00:07<00:00, 13.80it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 1ms/step
# Bootstrap sampling for general Sequential_NN: 100%|██████████| 100/100 [00:07<00:00, 13.42it/s]
# Bootstrap sampling for general LSTM:   0%|          | 0/100 [00:00<?, ?it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:   2%|▏         | 2/100 [00:00<00:07, 12.59it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:   4%|▍         | 4/100 [00:00<00:07, 13.22it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:   6%|▌         | 6/100 [00:00<00:06, 13.64it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:   8%|▊         | 8/100 [00:00<00:06, 13.40it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  10%|█         | 10/100 [00:00<00:06, 13.35it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  12%|█▏        | 12/100 [00:00<00:06, 13.04it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  14%|█▍        | 14/100 [00:01<00:06, 13.10it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  16%|█▌        | 16/100 [00:01<00:06, 13.14it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  18%|█▊        | 18/100 [00:01<00:06, 13.37it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  20%|██        | 20/100 [00:01<00:06, 13.16it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  22%|██▏       | 22/100 [00:01<00:05, 13.04it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  24%|██▍       | 24/100 [00:01<00:05, 13.21it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  26%|██▌       | 26/100 [00:01<00:05, 13.32it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  28%|██▊       | 28/100 [00:02<00:05, 13.21it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  30%|███       | 30/100 [00:02<00:05, 13.12it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  32%|███▏      | 32/100 [00:02<00:05, 13.30it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  34%|███▍      | 34/100 [00:02<00:04, 13.24it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  36%|███▌      | 36/100 [00:02<00:04, 13.32it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  38%|███▊      | 38/100 [00:02<00:04, 13.26it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  40%|████      | 40/100 [00:03<00:04, 12.92it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  42%|████▏     | 42/100 [00:03<00:04, 12.94it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  44%|████▍     | 44/100 [00:03<00:04, 13.01it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  46%|████▌     | 46/100 [00:03<00:04, 13.19it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  48%|████▊     | 48/100 [00:03<00:04, 12.91it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  50%|█████     | 50/100 [00:03<00:03, 13.10it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  52%|█████▏    | 52/100 [00:03<00:03, 13.15it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  54%|█████▍    | 54/100 [00:04<00:03, 13.12it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  56%|█████▌    | 56/100 [00:04<00:03, 13.09it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  58%|█████▊    | 58/100 [00:04<00:03, 13.27it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  60%|██████    | 60/100 [00:04<00:03, 13.27it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  62%|██████▏   | 62/100 [00:04<00:02, 13.32it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  64%|██████▍   | 64/100 [00:04<00:02, 13.35it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  66%|██████▌   | 66/100 [00:05<00:02, 13.10it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  68%|██████▊   | 68/100 [00:05<00:02, 13.14it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  70%|███████   | 70/100 [00:05<00:02, 13.24it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  72%|███████▏  | 72/100 [00:05<00:02, 13.37it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  74%|███████▍  | 74/100 [00:05<00:01, 13.15it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  76%|███████▌  | 76/100 [00:05<00:01, 13.32it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  78%|███████▊  | 78/100 [00:05<00:01, 13.46it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  80%|████████  | 80/100 [00:06<00:01, 13.15it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  82%|████████▏ | 82/100 [00:06<00:01, 13.28it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  84%|████████▍ | 84/100 [00:06<00:01, 13.26it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  86%|████████▌ | 86/100 [00:06<00:01, 13.24it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  88%|████████▊ | 88/100 [00:06<00:00, 13.25it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  90%|█████████ | 90/100 [00:06<00:00, 13.43it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  92%|█████████▏| 92/100 [00:06<00:00, 13.03it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  94%|█████████▍| 94/100 [00:07<00:00, 12.93it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  96%|█████████▌| 96/100 [00:07<00:00, 13.05it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM:  98%|█████████▊| 98/100 [00:07<00:00, 13.10it/s]
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Bootstrap sampling for general LSTM: 100%|██████████| 100/100 [00:07<00:00, 13.17it/s]
# Processing EDOs:   0%|          | 0/33 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Processing EDOs:   3%|▎         | 1/33 [00:12<06:41, 12.56s/it]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Processing EDOs:   6%|▌         | 2/33 [00:24<06:24, 12.39s/it]
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# ...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# Processing EDOs: 100%|██████████| 33/33 [06:54<00:00, 12.55s/it]
# Sequential_NN general predictions for the next period:
#      MORENA  PRIANPRD     OTROS
# 0  0.525546  0.406202  0.067395
# 95% Confidence Intervals for Sequential_NN:
# Lower - MORENA: 0.5124, PRIANPRD: 0.3920, OTROS: 0.0639
# Upper - MORENA: 0.5386, PRIANPRD: 0.4218, OTROS: 0.0708
#
# LSTM general predictions for the next period:
#     MORENA  PRIANPRD     OTROS
# 0  0.52857   0.40329  0.064108
# 95% Confidence Intervals for LSTM:
# Lower - MORENA: 0.5129, PRIANPRD: 0.3875, OTROS: 0.0611
# Upper - MORENA: 0.5440, PRIANPRD: 0.4206, OTROS: 0.0671
#
# Sequential_NN predictions per EDO for the next period:
#       MORENA  PRIANPRD     OTROS
# 1   0.382152  0.325424  0.064671
# 2   0.382152  0.325424  0.064671
# 3   0.382152  0.325424  0.064671
# 4   0.382152  0.325424  0.064671
# 5   0.382152  0.325424  0.064671
# 6   0.382152  0.325424  0.064671
# 7   0.382152  0.325424  0.064671
# 8   0.382152  0.325424  0.064671
# 9   0.382152  0.325424  0.064671
# 10  0.382152  0.325424  0.064671
# 11  0.382152  0.325424  0.064671
# 12  0.382152  0.325424  0.064671
# 13  0.382152  0.325424  0.064671
# 14  0.382152  0.325424  0.064671
# 15  0.382152  0.325424  0.064671
# 16  0.382152  0.325424  0.064671
# 17  0.382152  0.325424  0.064671
# 18  0.382152  0.325424  0.064671
# 19  0.382152  0.325424  0.064671
# 20  0.382152  0.325424  0.064671
# 21  0.382152  0.325424  0.064671
# 22  0.382152  0.325424  0.064671
# 23  0.382152  0.325424  0.064671
# 24  0.382152  0.325424  0.064671
# 25  0.382152  0.325424  0.064671
# 26  0.382152  0.325424  0.064671
# 27  0.382152  0.325424  0.064671
# 28  0.382152  0.325424  0.064671
# 29  0.382152  0.325424  0.064671
# 30  0.382152  0.325424  0.064671
# 31  0.382152  0.325424  0.064671
# 32  0.382152  0.325424  0.064671
# 99  0.382152  0.325424  0.064671
# 95% Confidence Intervals for Sequential_NN:
# 1: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 2: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 3: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 4: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 5: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 6: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 7: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 8: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 9: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 10: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 11: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 12: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 13: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 14: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 15: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 16: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 17: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 18: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 19: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 20: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 21: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 22: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 23: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 24: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 25: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 26: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 27: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 28: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 29: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 30: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 31: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 32: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
# 99: Lower - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#        Upper - MORENA: 0.3822, PRIANPRD: 0.3254, OTROS: 0.0647
#
# LSTM predictions per EDO for the next period:
#       MORENA  PRIANPRD     OTROS
# 1   0.532594  0.389942  0.051256
# 2   0.532594  0.389942  0.051256
# 3   0.532594  0.389942  0.051256
# 4   0.532594  0.389942  0.051256
# 5   0.532594  0.389942  0.051256
# 6   0.532594  0.389942  0.051256
# 7   0.532594  0.389942  0.051256
# 8   0.532594  0.389942  0.051256
# 9   0.532594  0.389942  0.051256
# 10  0.532594  0.389942  0.051256
# 11  0.532594  0.389942  0.051256
# 12  0.532594  0.389942  0.051256
# 13  0.532594  0.389942  0.051256
# 14  0.532594  0.389942  0.051256
# 15  0.532594  0.389942  0.051256
# 16  0.532594  0.389942  0.051256
# 17  0.532594  0.389942  0.051256
# 18  0.532594  0.389942  0.051256
# 19  0.532594  0.389942  0.051256
# 20  0.532594  0.389942  0.051256
# 21  0.532594  0.389942  0.051256
# 22  0.532594  0.389942  0.051256
# 23  0.532594  0.389942  0.051256
# 24  0.532594  0.389942  0.051256
# 25  0.532594  0.389942  0.051256
# 26  0.532594  0.389942  0.051256
# 27  0.532594  0.389942  0.051256
# 28  0.532594  0.389942  0.051256
# 29  0.532594  0.389942  0.051256
# 30  0.532594  0.389942  0.051256
# 31  0.532594  0.389942  0.051256
# 32  0.532594  0.389942  0.051256
# 99  0.532594  0.389942  0.051256
# 95% Confidence Intervals for LSTM:
# 1: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 2: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 3: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 4: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 5: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 6: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 7: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 8: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 9: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 10: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 11: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 12: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 13: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 14: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 15: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 16: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 17: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 18: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 19: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 20: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 21: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 22: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 23: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 24: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 25: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 26: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 27: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 28: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 29: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 30: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 31: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 32: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# 99: Lower - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
#        Upper - MORENA: 0.5326, PRIANPRD: 0.3899, OTROS: 0.0513
# Total execution time: 429.08 seconds

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize

# Function to predict 'MORENA' or 'PRIANPRD' given a specific level of 'PART'
def predict_morena_prianprd(part_value, edo, model_name, target='MORENA'):
    X_new_period_edo = X_features.mean(axis=0).reshape((1, -1)).astype(np.float32)
    col_name_edo = f'EDO_{edo}'
    col_name_part = 'PART'

    if col_name_edo in df.columns:
        col_index_edo = df.columns.get_loc(col_name_edo)
        X_new_period_edo[0, col_index_edo] = 1  # Add one-hot encoded EDO column

    # Set the value of 'PART'
    if col_name_part in df.columns:
        col_index_part = df.columns.get_loc(col_name_part)
        X_new_period_edo[0, col_index_part] = part_value

    X_new_period_edo_reshaped = X_new_period_edo.reshape((X_new_period_edo.shape[0], 1, X_new_period_edo.shape[1]))

    model = trained_models[model_name]
    if model_name == 'LSTM':
        preds = model.predict(X_new_period_edo_reshaped)
    else:
        preds = model.predict(X_new_period_edo)

    preds = preds.flatten()

    if target == 'MORENA':
        return -preds[0]  # Negative for maximization
    elif target == 'PRIANPRD':
        return -preds[1]  # Negative for maximization
    else:
        return 0

# Function to find the optimal 'PART' level for a specific EDO
def optimize_part_for_edo(edo, model_name, target='MORENA'):
    result = minimize(predict_morena_prianprd, x0=[0.5], args=(edo, model_name, target), bounds=[(0, 1)])
    return result.x[0], -result.fun

# Run optimization for each EDO
optimal_part_per_edo = {}

for edo in unique_edos:
    opt_part_morena, max_morena = optimize_part_for_edo(edo, 'Sequential_NN', 'MORENA')
    opt_part_prianprd, max_prianprd = optimize_part_for_edo(edo, 'Sequential_NN', 'PRIANPRD')

    optimal_part_per_edo[edo] = {
        'Optimal_PART_Morena': opt_part_morena,
        'Max_Morena': max_morena,
        'Optimal_PART_Prianprd': opt_part_prianprd,
        'Max_Prianprd': max_prianprd
    }

# Convert results to DataFrame for easy visualization
optimal_part_df = pd.DataFrame(optimal_part_per_edo).T
print(optimal_part_df)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
#     Optimal_PART_Morena  Max_Morena  Optimal_PART_Prianprd  Max_Prianprd
# 1                   0.5    0.382152                    0.5      0.325424
# 2                   0.5    0.382152                    0.5      0.325424
# 3                   0.5    0.382152                    0.5      0.325424
# 4                   0.5    0.382152                    0.5      0.325424
# 5                   0.5    0.382152                    0.5      0.325424
# 6                   0.5    0.382152                    0.5      0.325424
# 7                   0.5    0.382152                    0.5      0.325424
# 8                   0.5    0.382152                    0.5      0.325424
# 9                   0.5    0.382152                    0.5      0.325424
# 10                  0.5    0.382152                    0.5      0.325424
# 11                  0.5    0.382152                    0.5      0.325424
# 12                  0.5    0.382152                    0.5      0.325424
# 13                  0.5    0.382152                    0.5      0.325424
# 14                  0.5    0.382152                    0.5      0.325424
# 15                  0.5    0.382152                    0.5      0.325424
# 16                  0.5    0.382152                    0.5      0.325424
# 17                  0.5    0.382152                    0.5      0.325424
# 18                  0.5    0.382152                    0.5      0.325424
# 19                  0.5    0.382152                    0.5      0.325424
# 20                  0.5    0.382152                    0.5      0.325424
# 21                  0.5    0.382152                    0.5      0.325424
# 22                  0.5    0.382152                    0.5      0.325424
# 23                  0.5    0.382152                    0.5      0.325424
# 24                  0.5    0.382152                    0.5      0.325424
# 25                  0.5    0.382152                    0.5      0.325424
# 26                  0.5    0.382152                    0.5      0.325424
# 27                  0.5    0.382152                    0.5      0.325424
# 28                  0.5    0.382152                    0.5      0.325424
# 29                  0.5    0.382152                    0.5      0.325424
# 30                  0.5    0.382152                    0.5      0.325424
# 31                  0.5    0.382152                    0.5      0.325424
# 32                  0.5    0.382152                    0.5      0.325424
# 99                  0.5    0.382152                    0.5      0.325424

# %% [markdown]
# ##...............................................................
# ## **All together**

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize
from sklearn.utils import resample
from sklearn.metrics import mean_squared_error, mean_absolute_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# Ensure the data is in numpy array format and correct dtype
X_features = df.drop(columns=['TIPO', 'AÑO', 'MORENA', 'PRIANPRD', 'OTROS'])
y = df[['MORENA', 'PRIANPRD', 'OTROS']]

# Convert categorical 'EDO' column to numeric using one-hot encoding without dropping the first level
X_features = pd.get_dummies(X_features, columns=['EDO']).values.astype(np.float32)
y = y.values.astype(np.float32)

# Verify the data types
print(f"X_features dtype: {X_features.dtype}")
print(f"y dtype: {y.dtype}")

# Define function to calculate MAPE
def mean_absolute_percentage_error_custom(y_true, y_pred, threshold=1e-2):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    mask = y_true > threshold
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

# Define and train the Sequential Neural Network model
def build_sequential_nn(input_shape):
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=input_shape))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(3, activation='linear'))
    model.compile(optimizer='adam', loss='mse')
    return model

# Define and train the LSTM model
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=(1, input_shape)))
    model.add(Dense(3, activation='linear'))
    model.compile(optimizer='adam', loss='mse')
    return model

# Train and evaluate models
input_shape = (X_features.shape[1],)
X_features_reshaped = X_features.reshape((X_features.shape[0], 1, X_features.shape[1]))

models = {
    'Sequential_NN': build_sequential_nn(input_shape),
    'LSTM': build_lstm_model(X_features.shape[1])
}

trained_models = {}
mse_scores = {}
mae_scores = {}
mape_scores = {}

# Training models
for name, model in models.items():
    if name == 'LSTM':
        model.fit(X_features_reshaped, y, epochs=50, batch_size=32, verbose=0)
    else:
        model.fit(X_features, y, epochs=50, batch_size=32, verbose=0)

    preds = model.predict(X_features if name != 'LSTM' else X_features_reshaped)
    mse_scores[name] = mean_squared_error(y, preds)
    mae_scores[name] = mean_absolute_error(y, preds)
    mape_scores[name] = mean_absolute_percentage_error_custom(y, preds)
    trained_models[name] = model

# Create a DataFrame to display the errors of the selected models
errors_df = pd.DataFrame(
    [(model, mse_scores[model], mae_scores[model], mape_scores[model]) for model in models.keys()],
    columns=['Model', 'MSE', 'MAE', 'MAPE']
)

# Display the DataFrame with the errors
print("Selected Models with Errors:")
print(errors_df)

# Initialize dictionary to store predictions per EDO
predictions_per_edo = {}
ci_per_edo = {}

# Get unique labels in the 'EDO' column
unique_edos = df['EDO'].unique()

# Ensure the one-hot encoded columns exist
encoded_columns = [f'EDO_{edo}' for edo in unique_edos]
encoded_columns_in_df = [col for col in encoded_columns if col in df.columns]

# Define PART levels to evaluate
part_levels = [0.40, 0.50, 0.60]

# Initialize dictionary to store general predictions and confidence intervals
general_predictions = {}
general_ci = {}

# Calculate general predictions and confidence intervals for each PART level
for part_value in part_levels:
    for name in models.keys():
        preds_samples = []

        for _ in range(100):  # Reduced to 100 for faster computation
            X_resampled = resample(X_features).astype(np.float32)
            col_name_part = 'PART'
            if col_name_part in df.columns:
                col_index_part = df.columns.get_loc(col_name_part)
                X_resampled[:, col_index_part] = part_value

            if name == 'LSTM':
                X_resampled = X_resampled.reshape((X_resampled.shape[0], 1, X_resampled.shape[1]))
            preds_resampled = trained_models[name].predict(X_resampled)
            preds_samples.append(preds_resampled.mean(axis=0))

        preds_samples = np.array(preds_samples)
        preds_mean = preds_samples.mean(axis=0)
        preds_lower = np.percentile(preds_samples, 2.5, axis=0)
        preds_upper = np.percentile(preds_samples, 97.5, axis=0)

        general_predictions[(name, part_value)] = preds_mean
        general_ci[(name, part_value)] = (preds_lower, preds_upper)

# Iterate over each unique 'EDO' label and PART levels
for edo in unique_edos:
    for part_value in part_levels:
        # Create a dummy data point for prediction for the given EDO
        X_new_period_edo = X_features.mean(axis=0).reshape((1, -1)).astype(np.float32)

        # Check if the one-hot encoded column for this EDO exists
        col_name_edo = f'EDO_{edo}'
        col_name_part = 'PART'
        if col_name_edo in encoded_columns_in_df:
            col_index_edo = df.columns.get_loc(col_name_edo)
            X_new_period_edo[0, col_index_edo] = 1  # Add one-hot encoded EDO column

        # Set the value of PART
        if col_name_part in df.columns:
            col_index_part = df.columns.get_loc(col_name_part)
            X_new_period_edo[0, col_index_part] = part_value

        X_new_period_edo_reshaped = X_new_period_edo.reshape((X_new_period_edo.shape[0], 1, X_new_period_edo.shape[1]))

        # Store predictions and confidence intervals for the selected models
        for name in models.keys():
            preds_samples = []
            for _ in range(100):
                preds_resampled = trained_models[name].predict(X_new_period_edo if name != 'LSTM' else X_new_period_edo_reshaped)
                preds_samples.append(preds_resampled.flatten())

            preds_samples = np.array(preds_samples)
            preds_mean = preds_samples.mean(axis=0)
            preds_lower = np.percentile(preds_samples, 2.5, axis=0)
            preds_upper = np.percentile(preds_samples, 97.5, axis=0)

            predictions_per_edo.setdefault((edo, name, part_value), []).append(preds_mean)
            ci_per_edo.setdefault((edo, name, part_value), []).append((preds_lower, preds_upper))

# Convert general predictions to DataFrames and add labels
general_predictions_df = {key: pd.DataFrame([preds], columns=['MORENA', 'PRIANPRD', 'OTROS']) for key, preds in general_predictions.items()}

# Convert EDO predictions to DataFrames and add labels
predictions_df_per_edo = {key: pd.DataFrame(preds, columns=['MORENA', 'PRIANPRD', 'OTROS']) for key, preds in predictions_per_edo.items()}

# Display the general predictions and confidence intervals
for (model_name, part_value), df in general_predictions_df.items():
    print(f"\n{model_name} general predictions for PART = {part_value}:")
    print(df)
    lower_ci = general_ci[(model_name, part_value)][0]
    upper_ci = general_ci[(model_name, part_value)][1]
    print(f"95% Confidence Intervals for {model_name} at PART = {part_value}:")
    print(f"Lower - MORENA: {lower_ci[0]:.4f}, PRIANPRD: {lower_ci[1]:.4f}, OTROS: {lower_ci[2]:.4f}")
    print(f"Upper - MORENA: {upper_ci[0]:.4f}, PRIANPRD: {upper_ci[1]:.4f}, OTROS: {upper_ci[2]:.4f}")

# Display the DataFrames with EDO predictions and confidence intervals
for (edo, model_name, part_value), df in predictions_df_per_edo.items():
    print(f"\n{model_name} predictions per EDO = {edo} for PART = {part_value}:")
    print(df)
    # Debugging prints to check ci_per_edo content
    print(f"ci_per_edo[{(edo, model_name, part_value)}]: {ci_per_edo[(edo, model_name, part_value)]}")
    if len(ci_per_edo[(edo, model_name, part_value)]) < 2:
        print(f"Error: ci_per_edo[{(edo, model_name, part_value)}] has less than 2 elements.")
        continue
    lower_ci = ci_per_edo[(edo, model_name, part_value)][0]
    upper_ci = ci_per_edo[(edo, model_name, part_value)][1]
    print(f"95% Confidence Intervals for {model_name} at PART = {part_value}, EDO = {edo}:")
    print(f"Lower - MORENA: {lower_ci[0]:.4f}, PRIANPRD: {lower_ci[1]:.4f}, OTROS: {lower_ci[2]:.4f}")
    print(f"Upper - MORENA: {upper_ci[0]:.4f}, PRIANPRD: {upper_ci[1]:.4f}, OTROS: {upper_ci[2]:.4f}")
# Out:
# X_features dtype: float32
# y dtype: float32
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# ...
# Error: ci_per_edo[(25, 'Sequential_NN', 0.5)] has less than 2 elements.
#
# LSTM predictions per EDO = 25 for PART = 0.5:
#      MORENA  PRIANPRD     OTROS
# 0  0.544228  0.390664  0.071581
# ci_per_edo[(25, 'LSTM', 0.5)]: [(array([0.5442279 , 0.39066443, 0.07158151]), array([0.5442279 , 0.39066443, 0.07158151]))]
# Error: ci_per_edo[(25, 'LSTM', 0.5)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 25 for PART = 0.6:
#      MORENA  PRIANPRD     OTROS
# 0  0.500557   0.35325  0.066083
# ci_per_edo[(25, 'Sequential_NN', 0.6)]: [(array([0.50055677, 0.35325032, 0.06608271]), array([0.50055677, 0.35325032, 0.06608271]))]
# Error: ci_per_edo[(25, 'Sequential_NN', 0.6)] has less than 2 elements.
#
# LSTM predictions per EDO = 25 for PART = 0.6:
#    MORENA  PRIANPRD     OTROS
# 0  0.5508  0.393175  0.071904
# ci_per_edo[(25, 'LSTM', 0.6)]: [(array([0.55079997, 0.39317498, 0.07190429]), array([0.55079997, 0.39317498, 0.07190429]))]
# Error: ci_per_edo[(25, 'LSTM', 0.6)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 26 for PART = 0.4:
#      MORENA  PRIANPRD     OTROS
# 0  0.472252  0.346743  0.053119
# ci_per_edo[(26, 'Sequential_NN', 0.4)]: [(array([0.47225127, 0.34674332, 0.05311942]), array([0.47225127, 0.34674332, 0.05311942]))]
# Error: ci_per_edo[(26, 'Sequential_NN', 0.4)] has less than 2 elements.
#
# LSTM predictions per EDO = 26 for PART = 0.4:
#     MORENA  PRIANPRD     OTROS
# 0  0.53848   0.38855  0.071256
# ci_per_edo[(26, 'LSTM', 0.4)]: [(array([0.5384801 , 0.38855016, 0.07125596]), array([0.5384801 , 0.38855016, 0.07125596]))]
# Error: ci_per_edo[(26, 'LSTM', 0.4)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 26 for PART = 0.5:
#     MORENA  PRIANPRD     OTROS
# 0  0.48541  0.346535  0.061298
# ci_per_edo[(26, 'Sequential_NN', 0.5)]: [(array([0.48541054, 0.34653535, 0.06129792]), array([0.48541054, 0.34653535, 0.06129792]))]
# Error: ci_per_edo[(26, 'Sequential_NN', 0.5)] has less than 2 elements.
#
# LSTM predictions per EDO = 26 for PART = 0.5:
#      MORENA  PRIANPRD     OTROS
# 0  0.544228  0.390664  0.071581
# ci_per_edo[(26, 'LSTM', 0.5)]: [(array([0.5442279 , 0.39066443, 0.07158151]), array([0.5442279 , 0.39066443, 0.07158151]))]
# Error: ci_per_edo[(26, 'LSTM', 0.5)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 26 for PART = 0.6:
#      MORENA  PRIANPRD     OTROS
# 0  0.500557   0.35325  0.066083
# ci_per_edo[(26, 'Sequential_NN', 0.6)]: [(array([0.50055677, 0.35325032, 0.06608271]), array([0.50055677, 0.35325032, 0.06608271]))]
# Error: ci_per_edo[(26, 'Sequential_NN', 0.6)] has less than 2 elements.
#
# LSTM predictions per EDO = 26 for PART = 0.6:
#    MORENA  PRIANPRD     OTROS
# 0  0.5508  0.393175  0.071904
# ci_per_edo[(26, 'LSTM', 0.6)]: [(array([0.55079997, 0.39317498, 0.07190429]), array([0.55079997, 0.39317498, 0.07190429]))]
# Error: ci_per_edo[(26, 'LSTM', 0.6)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 27 for PART = 0.4:
#      MORENA  PRIANPRD     OTROS
# 0  0.472252  0.346743  0.053119
# ci_per_edo[(27, 'Sequential_NN', 0.4)]: [(array([0.47225127, 0.34674332, 0.05311942]), array([0.47225127, 0.34674332, 0.05311942]))]
# Error: ci_per_edo[(27, 'Sequential_NN', 0.4)] has less than 2 elements.
#
# LSTM predictions per EDO = 27 for PART = 0.4:
#     MORENA  PRIANPRD     OTROS
# 0  0.53848   0.38855  0.071256
# ci_per_edo[(27, 'LSTM', 0.4)]: [(array([0.5384801 , 0.38855016, 0.07125596]), array([0.5384801 , 0.38855016, 0.07125596]))]
# Error: ci_per_edo[(27, 'LSTM', 0.4)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 27 for PART = 0.5:
#     MORENA  PRIANPRD     OTROS
# 0  0.48541  0.346535  0.061298
# ci_per_edo[(27, 'Sequential_NN', 0.5)]: [(array([0.48541054, 0.34653535, 0.06129792]), array([0.48541054, 0.34653535, 0.06129792]))]
# Error: ci_per_edo[(27, 'Sequential_NN', 0.5)] has less than 2 elements.
#
# LSTM predictions per EDO = 27 for PART = 0.5:
#      MORENA  PRIANPRD     OTROS
# 0  0.544228  0.390664  0.071581
# ci_per_edo[(27, 'LSTM', 0.5)]: [(array([0.5442279 , 0.39066443, 0.07158151]), array([0.5442279 , 0.39066443, 0.07158151]))]
# Error: ci_per_edo[(27, 'LSTM', 0.5)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 27 for PART = 0.6:
#      MORENA  PRIANPRD     OTROS
# 0  0.500557   0.35325  0.066083
# ci_per_edo[(27, 'Sequential_NN', 0.6)]: [(array([0.50055677, 0.35325032, 0.06608271]), array([0.50055677, 0.35325032, 0.06608271]))]
# Error: ci_per_edo[(27, 'Sequential_NN', 0.6)] has less than 2 elements.
#
# LSTM predictions per EDO = 27 for PART = 0.6:
#    MORENA  PRIANPRD     OTROS
# 0  0.5508  0.393175  0.071904
# ci_per_edo[(27, 'LSTM', 0.6)]: [(array([0.55079997, 0.39317498, 0.07190429]), array([0.55079997, 0.39317498, 0.07190429]))]
# Error: ci_per_edo[(27, 'LSTM', 0.6)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 28 for PART = 0.4:
#      MORENA  PRIANPRD     OTROS
# 0  0.472252  0.346743  0.053119
# ci_per_edo[(28, 'Sequential_NN', 0.4)]: [(array([0.47225127, 0.34674332, 0.05311942]), array([0.47225127, 0.34674332, 0.05311942]))]
# Error: ci_per_edo[(28, 'Sequential_NN', 0.4)] has less than 2 elements.
#
# LSTM predictions per EDO = 28 for PART = 0.4:
#     MORENA  PRIANPRD     OTROS
# 0  0.53848   0.38855  0.071256
# ci_per_edo[(28, 'LSTM', 0.4)]: [(array([0.5384801 , 0.38855016, 0.07125596]), array([0.5384801 , 0.38855016, 0.07125596]))]
# Error: ci_per_edo[(28, 'LSTM', 0.4)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 28 for PART = 0.5:
#     MORENA  PRIANPRD     OTROS
# 0  0.48541  0.346535  0.061298
# ci_per_edo[(28, 'Sequential_NN', 0.5)]: [(array([0.48541054, 0.34653535, 0.06129792]), array([0.48541054, 0.34653535, 0.06129792]))]
# Error: ci_per_edo[(28, 'Sequential_NN', 0.5)] has less than 2 elements.
#
# LSTM predictions per EDO = 28 for PART = 0.5:
#      MORENA  PRIANPRD     OTROS
# 0  0.544228  0.390664  0.071581
# ci_per_edo[(28, 'LSTM', 0.5)]: [(array([0.5442279 , 0.39066443, 0.07158151]), array([0.5442279 , 0.39066443, 0.07158151]))]
# Error: ci_per_edo[(28, 'LSTM', 0.5)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 28 for PART = 0.6:
#      MORENA  PRIANPRD     OTROS
# 0  0.500557   0.35325  0.066083
# ci_per_edo[(28, 'Sequential_NN', 0.6)]: [(array([0.50055677, 0.35325032, 0.06608271]), array([0.50055677, 0.35325032, 0.06608271]))]
# Error: ci_per_edo[(28, 'Sequential_NN', 0.6)] has less than 2 elements.
#
# LSTM predictions per EDO = 28 for PART = 0.6:
#    MORENA  PRIANPRD     OTROS
# 0  0.5508  0.393175  0.071904
# ci_per_edo[(28, 'LSTM', 0.6)]: [(array([0.55079997, 0.39317498, 0.07190429]), array([0.55079997, 0.39317498, 0.07190429]))]
# Error: ci_per_edo[(28, 'LSTM', 0.6)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 29 for PART = 0.4:
#      MORENA  PRIANPRD     OTROS
# 0  0.472252  0.346743  0.053119
# ci_per_edo[(29, 'Sequential_NN', 0.4)]: [(array([0.47225127, 0.34674332, 0.05311942]), array([0.47225127, 0.34674332, 0.05311942]))]
# Error: ci_per_edo[(29, 'Sequential_NN', 0.4)] has less than 2 elements.
#
# LSTM predictions per EDO = 29 for PART = 0.4:
#     MORENA  PRIANPRD     OTROS
# 0  0.53848   0.38855  0.071256
# ci_per_edo[(29, 'LSTM', 0.4)]: [(array([0.5384801 , 0.38855016, 0.07125596]), array([0.5384801 , 0.38855016, 0.07125596]))]
# Error: ci_per_edo[(29, 'LSTM', 0.4)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 29 for PART = 0.5:
#     MORENA  PRIANPRD     OTROS
# 0  0.48541  0.346535  0.061298
# ci_per_edo[(29, 'Sequential_NN', 0.5)]: [(array([0.48541054, 0.34653535, 0.06129792]), array([0.48541054, 0.34653535, 0.06129792]))]
# Error: ci_per_edo[(29, 'Sequential_NN', 0.5)] has less than 2 elements.
#
# LSTM predictions per EDO = 29 for PART = 0.5:
#      MORENA  PRIANPRD     OTROS
# 0  0.544228  0.390664  0.071581
# ci_per_edo[(29, 'LSTM', 0.5)]: [(array([0.5442279 , 0.39066443, 0.07158151]), array([0.5442279 , 0.39066443, 0.07158151]))]
# Error: ci_per_edo[(29, 'LSTM', 0.5)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 29 for PART = 0.6:
#      MORENA  PRIANPRD     OTROS
# 0  0.500557   0.35325  0.066083
# ci_per_edo[(29, 'Sequential_NN', 0.6)]: [(array([0.50055677, 0.35325032, 0.06608271]), array([0.50055677, 0.35325032, 0.06608271]))]
# Error: ci_per_edo[(29, 'Sequential_NN', 0.6)] has less than 2 elements.
#
# LSTM predictions per EDO = 29 for PART = 0.6:
#    MORENA  PRIANPRD     OTROS
# 0  0.5508  0.393175  0.071904
# ci_per_edo[(29, 'LSTM', 0.6)]: [(array([0.55079997, 0.39317498, 0.07190429]), array([0.55079997, 0.39317498, 0.07190429]))]
# Error: ci_per_edo[(29, 'LSTM', 0.6)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 30 for PART = 0.4:
#      MORENA  PRIANPRD     OTROS
# 0  0.472252  0.346743  0.053119
# ci_per_edo[(30, 'Sequential_NN', 0.4)]: [(array([0.47225127, 0.34674332, 0.05311942]), array([0.47225127, 0.34674332, 0.05311942]))]
# Error: ci_per_edo[(30, 'Sequential_NN', 0.4)] has less than 2 elements.
#
# LSTM predictions per EDO = 30 for PART = 0.4:
#     MORENA  PRIANPRD     OTROS
# 0  0.53848   0.38855  0.071256
# ci_per_edo[(30, 'LSTM', 0.4)]: [(array([0.5384801 , 0.38855016, 0.07125596]), array([0.5384801 , 0.38855016, 0.07125596]))]
# Error: ci_per_edo[(30, 'LSTM', 0.4)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 30 for PART = 0.5:
#     MORENA  PRIANPRD     OTROS
# 0  0.48541  0.346535  0.061298
# ci_per_edo[(30, 'Sequential_NN', 0.5)]: [(array([0.48541054, 0.34653535, 0.06129792]), array([0.48541054, 0.34653535, 0.06129792]))]
# Error: ci_per_edo[(30, 'Sequential_NN', 0.5)] has less than 2 elements.
#
# LSTM predictions per EDO = 30 for PART = 0.5:
#      MORENA  PRIANPRD     OTROS
# 0  0.544228  0.390664  0.071581
# ci_per_edo[(30, 'LSTM', 0.5)]: [(array([0.5442279 , 0.39066443, 0.07158151]), array([0.5442279 , 0.39066443, 0.07158151]))]
# Error: ci_per_edo[(30, 'LSTM', 0.5)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 30 for PART = 0.6:
#      MORENA  PRIANPRD     OTROS
# 0  0.500557   0.35325  0.066083
# ci_per_edo[(30, 'Sequential_NN', 0.6)]: [(array([0.50055677, 0.35325032, 0.06608271]), array([0.50055677, 0.35325032, 0.06608271]))]
# Error: ci_per_edo[(30, 'Sequential_NN', 0.6)] has less than 2 elements.
#
# LSTM predictions per EDO = 30 for PART = 0.6:
#    MORENA  PRIANPRD     OTROS
# 0  0.5508  0.393175  0.071904
# ci_per_edo[(30, 'LSTM', 0.6)]: [(array([0.55079997, 0.39317498, 0.07190429]), array([0.55079997, 0.39317498, 0.07190429]))]
# Error: ci_per_edo[(30, 'LSTM', 0.6)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 31 for PART = 0.4:
#      MORENA  PRIANPRD     OTROS
# 0  0.472252  0.346743  0.053119
# ci_per_edo[(31, 'Sequential_NN', 0.4)]: [(array([0.47225127, 0.34674332, 0.05311942]), array([0.47225127, 0.34674332, 0.05311942]))]
# Error: ci_per_edo[(31, 'Sequential_NN', 0.4)] has less than 2 elements.
#
# LSTM predictions per EDO = 31 for PART = 0.4:
#     MORENA  PRIANPRD     OTROS
# 0  0.53848   0.38855  0.071256
# ci_per_edo[(31, 'LSTM', 0.4)]: [(array([0.5384801 , 0.38855016, 0.07125596]), array([0.5384801 , 0.38855016, 0.07125596]))]
# Error: ci_per_edo[(31, 'LSTM', 0.4)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 31 for PART = 0.5:
#     MORENA  PRIANPRD     OTROS
# 0  0.48541  0.346535  0.061298
# ci_per_edo[(31, 'Sequential_NN', 0.5)]: [(array([0.48541054, 0.34653535, 0.06129792]), array([0.48541054, 0.34653535, 0.06129792]))]
# Error: ci_per_edo[(31, 'Sequential_NN', 0.5)] has less than 2 elements.
#
# LSTM predictions per EDO = 31 for PART = 0.5:
#      MORENA  PRIANPRD     OTROS
# 0  0.544228  0.390664  0.071581
# ci_per_edo[(31, 'LSTM', 0.5)]: [(array([0.5442279 , 0.39066443, 0.07158151]), array([0.5442279 , 0.39066443, 0.07158151]))]
# Error: ci_per_edo[(31, 'LSTM', 0.5)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 31 for PART = 0.6:
#      MORENA  PRIANPRD     OTROS
# 0  0.500557   0.35325  0.066083
# ci_per_edo[(31, 'Sequential_NN', 0.6)]: [(array([0.50055677, 0.35325032, 0.06608271]), array([0.50055677, 0.35325032, 0.06608271]))]
# Error: ci_per_edo[(31, 'Sequential_NN', 0.6)] has less than 2 elements.
#
# LSTM predictions per EDO = 31 for PART = 0.6:
#    MORENA  PRIANPRD     OTROS
# 0  0.5508  0.393175  0.071904
# ci_per_edo[(31, 'LSTM', 0.6)]: [(array([0.55079997, 0.39317498, 0.07190429]), array([0.55079997, 0.39317498, 0.07190429]))]
# Error: ci_per_edo[(31, 'LSTM', 0.6)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 32 for PART = 0.4:
#      MORENA  PRIANPRD     OTROS
# 0  0.472252  0.346743  0.053119
# ci_per_edo[(32, 'Sequential_NN', 0.4)]: [(array([0.47225127, 0.34674332, 0.05311942]), array([0.47225127, 0.34674332, 0.05311942]))]
# Error: ci_per_edo[(32, 'Sequential_NN', 0.4)] has less than 2 elements.
#
# LSTM predictions per EDO = 32 for PART = 0.4:
#     MORENA  PRIANPRD     OTROS
# 0  0.53848   0.38855  0.071256
# ci_per_edo[(32, 'LSTM', 0.4)]: [(array([0.5384801 , 0.38855016, 0.07125596]), array([0.5384801 , 0.38855016, 0.07125596]))]
# Error: ci_per_edo[(32, 'LSTM', 0.4)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 32 for PART = 0.5:
#     MORENA  PRIANPRD     OTROS
# 0  0.48541  0.346535  0.061298
# ci_per_edo[(32, 'Sequential_NN', 0.5)]: [(array([0.48541054, 0.34653535, 0.06129792]), array([0.48541054, 0.34653535, 0.06129792]))]
# Error: ci_per_edo[(32, 'Sequential_NN', 0.5)] has less than 2 elements.
#
# LSTM predictions per EDO = 32 for PART = 0.5:
#      MORENA  PRIANPRD     OTROS
# 0  0.544228  0.390664  0.071581
# ci_per_edo[(32, 'LSTM', 0.5)]: [(array([0.5442279 , 0.39066443, 0.07158151]), array([0.5442279 , 0.39066443, 0.07158151]))]
# Error: ci_per_edo[(32, 'LSTM', 0.5)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 32 for PART = 0.6:
#      MORENA  PRIANPRD     OTROS
# 0  0.500557   0.35325  0.066083
# ci_per_edo[(32, 'Sequential_NN', 0.6)]: [(array([0.50055677, 0.35325032, 0.06608271]), array([0.50055677, 0.35325032, 0.06608271]))]
# Error: ci_per_edo[(32, 'Sequential_NN', 0.6)] has less than 2 elements.
#
# LSTM predictions per EDO = 32 for PART = 0.6:
#    MORENA  PRIANPRD     OTROS
# 0  0.5508  0.393175  0.071904
# ci_per_edo[(32, 'LSTM', 0.6)]: [(array([0.55079997, 0.39317498, 0.07190429]), array([0.55079997, 0.39317498, 0.07190429]))]
# Error: ci_per_edo[(32, 'LSTM', 0.6)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 99 for PART = 0.4:
#      MORENA  PRIANPRD     OTROS
# 0  0.472252  0.346743  0.053119
# ci_per_edo[(99, 'Sequential_NN', 0.4)]: [(array([0.47225127, 0.34674332, 0.05311942]), array([0.47225127, 0.34674332, 0.05311942]))]
# Error: ci_per_edo[(99, 'Sequential_NN', 0.4)] has less than 2 elements.
#
# LSTM predictions per EDO = 99 for PART = 0.4:
#     MORENA  PRIANPRD     OTROS
# 0  0.53848   0.38855  0.071256
# ci_per_edo[(99, 'LSTM', 0.4)]: [(array([0.5384801 , 0.38855016, 0.07125596]), array([0.5384801 , 0.38855016, 0.07125596]))]
# Error: ci_per_edo[(99, 'LSTM', 0.4)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 99 for PART = 0.5:
#     MORENA  PRIANPRD     OTROS
# 0  0.48541  0.346535  0.061298
# ci_per_edo[(99, 'Sequential_NN', 0.5)]: [(array([0.48541054, 0.34653535, 0.06129792]), array([0.48541054, 0.34653535, 0.06129792]))]
# Error: ci_per_edo[(99, 'Sequential_NN', 0.5)] has less than 2 elements.
#
# LSTM predictions per EDO = 99 for PART = 0.5:
#      MORENA  PRIANPRD     OTROS
# 0  0.544228  0.390664  0.071581
# ci_per_edo[(99, 'LSTM', 0.5)]: [(array([0.5442279 , 0.39066443, 0.07158151]), array([0.5442279 , 0.39066443, 0.07158151]))]
# Error: ci_per_edo[(99, 'LSTM', 0.5)] has less than 2 elements.
#
# Sequential_NN predictions per EDO = 99 for PART = 0.6:
#      MORENA  PRIANPRD     OTROS
# 0  0.500557   0.35325  0.066083
# ci_per_edo[(99, 'Sequential_NN', 0.6)]: [(array([0.50055677, 0.35325032, 0.06608271]), array([0.50055677, 0.35325032, 0.06608271]))]
# Error: ci_per_edo[(99, 'Sequential_NN', 0.6)] has less than 2 elements.
#
# LSTM predictions per EDO = 99 for PART = 0.6:
#    MORENA  PRIANPRD     OTROS
# 0  0.5508  0.393175  0.071904
# ci_per_edo[(99, 'LSTM', 0.6)]: [(array([0.55079997, 0.39317498, 0.07190429]), array([0.55079997, 0.39317498, 0.07190429]))]
# Error: ci_per_edo[(99, 'LSTM', 0.6)] has less than 2 elements.
